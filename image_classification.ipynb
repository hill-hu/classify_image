# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
#from urllib.request import urlretrieve
from os.path import isfile, isdir
import unittest
import problem_unittests as tests


cifar10_dataset_folder_path = 'cifar-10-batches-py'




tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    n=np.divide(x,255)
    return n


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn import preprocessing
map_class=None
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    lib=preprocessing.LabelBinarizer()
    # use a global var for holding the map of encoding
    global map_class
    if(map_class is None):
        lib.fit(x) 
        map_class=lib.classes_        
    else:
        lib.classes_=map_class


    return lib.transform(x)  


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shp=[None]+list(image_shape)
    m=tf.placeholder(tf.float32,shape=tuple(shp),name='x')
    return m


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    shp=(None,n_classes)
 
    m=tf.placeholder(tf.float32,shape=(shp),name='y')
    return m


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    m=tf.placeholder(tf.float32,None,name='keep_prob')
    return m


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
   
    print(conv_strides)
    dimension=x_tensor.get_shape().as_list()
    shape=list( conv_ksize+(dimension[-1],)+(conv_num_outputs,))
    print(shape)
    filter_weights=tf.Variable( tf.truncated_normal(shape,0,0.1))
    filter_bias=tf.Variable(tf.zeros(conv_num_outputs))
    padding='SAME'

    strides=list((1,)+conv_strides+(1,))
    conv_layer=tf.nn.conv2d(x_tensor,filter_weights,strides=strides,padding='SAME')
    conv_layer=tf.nn.bias_add(conv_layer,filter_bias)
    conv_layer=tf.nn.relu(conv_layer)
    pool_ksize=[1]+list(pool_ksize)+[1]
    pool_strides=[1]+list(pool_strides)+[1]   
    conv_layer=tf.nn.max_pool(conv_layer,ksize=pool_ksize,strides=pool_strides,padding=padding)
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# (4, 4)
# [2, 2, 5, 10]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
from numpy import prod
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    dimension=x_tensor.get_shape().as_list()
    print(dimension)
    dim_new=tf.reshape(x_tensor,[-1,prod(dimension[1:])])
    print(dim_new)
    return dim_new


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# [None, 10, 30, 6]
# Tensor("Reshape:0", shape=(?, 1800), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimension=x_tensor.get_shape().as_list()
    shape=list((dimension[-1],)+(num_outputs,))
    
    print(shape)
    weight=tf.Variable(tf.truncated_normal(shape,0,0.1))
    bias=tf.Variable(tf.zeros(num_outputs))
    add_weight=tf.matmul(x_tensor,weight)
    add_bias=tf.add(add_weight,bias)
    full=tf.nn.relu(add_bias)
    return full


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# [128, 40]
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print(x_tensor)
    dimension=x_tensor.get_shape().as_list()
    shape=list((dimension[-1],)+(num_outputs,))
    weight=tf.Variable(tf.truncated_normal(shape,0,0.1))
    bias=tf.Variable(tf.zeros(num_outputs))
    add_weight=tf.matmul(x_tensor,weight)
    
    return tf.add(add_weight,bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tensor("Placeholder_3:0", shape=(?, 128), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    num_outputs=10
    model=conv2d_maxpool(x,conv_num_outputs=num_outputs,conv_ksize=(4,4),conv_strides=(1,1),pool_ksize=(8,8),pool_strides=(1,1))
    #model=conv2d_maxpool(x,18,(4,4),(1,1),pool_ksize=(8,8),pool_strides=(1,1))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    model=flatten(model)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully_conn(model, num_outputs)
    model=tf.nn.dropout(model,keep_prob)    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_value=output(model,num_outputs)
    
    # TODO: return output
    return output_value


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (1, 1)
# [4, 4, 3, 10]
# [None, 32, 32, 10]
# Tensor("Reshape:0", shape=(?, 10240), dtype=float32)
# [10240, 10]
# Tensor("dropout/mul:0", shape=(?, 10240), dtype=float32)
# (1, 1)
# [4, 4, 3, 10]
# [None, 32, 32, 10]
# Tensor("Reshape_4:0", shape=(?, 10240), dtype=float32)
# [10240, 10]
# Tensor("dropout_1/mul:0", shape=(?, 10240), dtype=float32)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch,y:label_batch,keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss=session.run(cost,feed_dict={x:feature_batch,y:label_batch,keep_prob:1.0})
    valid_acc=session.run(accuracy,feed_dict={x:valid_features,y:valid_labels,keep_prob:1.0})
    print("Loss:{:>10.4f} validation accuracy :{:.4f}".format(loss,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:    2.1976 validation accuracy :0.1848
# Epoch  2, CIFAR-10 Batch 1:  Loss:    2.1045 validation accuracy :0.2492
# Epoch  3, CIFAR-10 Batch 1:  Loss:    1.9931 validation accuracy :0.3144
# Epoch  4, CIFAR-10 Batch 1:  Loss:    1.8780 validation accuracy :0.3492
# Epoch  5, CIFAR-10 Batch 1:  Loss:    1.8010 validation accuracy :0.3726
# Epoch  6, CIFAR-10 Batch 1:  Loss:    1.7518 validation accuracy :0.3838
# Epoch  7, CIFAR-10 Batch 1:  Loss:    1.7088 validation accuracy :0.4072
# Epoch  8, CIFAR-10 Batch 1:  Loss:    1.6720 validation accuracy :0.4154
# Epoch  9, CIFAR-10 Batch 1:  Loss:    1.6529 validation accuracy :0.4238
# Epoch 10, CIFAR-10 Batch 1:  Loss:    1.6259 validation accuracy :0.4290
# Epoch 11, CIFAR-10 Batch 1:  Loss:    1.6040 validation accuracy :0.4302
# Epoch 12, CIFAR-10 Batch 1:  Loss:    1.5790 validation accuracy :0.4366
# Epoch 13, CIFAR-10 Batch 1:  Loss:    1.5666 validation accuracy :0.4444
# Epoch 14, CIFAR-10 Batch 1:  Loss:    1.5506 validation accuracy :0.4466
# Epoch 15, CIFAR-10 Batch 1:  Loss:    1.5427 validation accuracy :0.4514
# Epoch 16, CIFAR-10 Batch 1:  Loss:    1.5114 validation accuracy :0.4494
# Epoch 17, CIFAR-10 Batch 1:  Loss:    1.5105 validation accuracy :0.4538
# Epoch 18, CIFAR-10 Batch 1:  Loss:    1.4812 validation accuracy :0.4624
# Epoch 19, CIFAR-10 Batch 1:  Loss:    1.4645 validation accuracy :0.4646
# Epoch 20, CIFAR-10 Batch 1:  Loss:    1.4467 validation accuracy :0.4676
# Epoch 21, CIFAR-10 Batch 1:  Loss:    1.4414 validation accuracy :0.4700
# Epoch 22, CIFAR-10 Batch 1:  Loss:    1.4194 validation accuracy :0.4756
# Epoch 23, CIFAR-10 Batch 1:  Loss:    1.4000 validation accuracy :0.4790
# Epoch 24, CIFAR-10 Batch 1:  Loss:    1.3805 validation accuracy :0.4854
# Epoch 25, CIFAR-10 Batch 1:  Loss:    1.3688 validation accuracy :0.4922
# Epoch 26, CIFAR-10 Batch 1:  Loss:    1.3562 validation accuracy :0.4926
# Epoch 27, CIFAR-10 Batch 1:  Loss:    1.3381 validation accuracy :0.4950
# Epoch 28, CIFAR-10 Batch 1:  Loss:    1.3214 validation accuracy :0.4986
# Epoch 29, CIFAR-10 Batch 1:  Loss:    1.3103 validation accuracy :0.4978
# Epoch 30, CIFAR-10 Batch 1:  Loss:    1.2917 validation accuracy :0.5074
# Epoch 31, CIFAR-10 Batch 1:  Loss:    1.2795 validation accuracy :0.5076
# Epoch 32, CIFAR-10 Batch 1:  Loss:    1.2720 validation accuracy :0.5102
# Epoch 33, CIFAR-10 Batch 1:  Loss:    1.2564 validation accuracy :0.5122
# Epoch 34, CIFAR-10 Batch 1:  Loss:    1.2537 validation accuracy :0.5142
# Epoch 35, CIFAR-10 Batch 1:  Loss:    1.2332 validation accuracy :0.5150
# Epoch 36, CIFAR-10 Batch 1:  Loss:    1.2216 validation accuracy :0.5254
# Epoch 37, CIFAR-10 Batch 1:  Loss:    1.2100 validation accuracy :0.5238
# Epoch 38, CIFAR-10 Batch 1:  Loss:    1.1978 validation accuracy :0.5216
# Epoch 39, CIFAR-10 Batch 1:  Loss:    1.1865 validation accuracy :0.5248
# Epoch 40, CIFAR-10 Batch 1:  Loss:    1.1844 validation accuracy :0.5238
# Epoch 41, CIFAR-10 Batch 1:  Loss:    1.1727 validation accuracy :0.5286
# Epoch 42, CIFAR-10 Batch 1:  Loss:    1.1698 validation accuracy :0.5278
# Epoch 43, CIFAR-10 Batch 1:  Loss:    1.1641 validation accuracy :0.5284
# Epoch 44, CIFAR-10 Batch 1:  Loss:    1.1466 validation accuracy :0.5308
# Epoch 45, CIFAR-10 Batch 1:  Loss:    1.1401 validation accuracy :0.5314
# Epoch 46, CIFAR-10 Batch 1:  Loss:    1.1318 validation accuracy :0.5312
# Epoch 47, CIFAR-10 Batch 1:  Loss:    1.1290 validation accuracy :0.5352
# Epoch 48, CIFAR-10 Batch 1:  Loss:    1.1176 validation accuracy :0.5362
# Epoch 49, CIFAR-10 Batch 1:  Loss:    1.1189 validation accuracy :0.5332
# Epoch 50, CIFAR-10 Batch 1:  Loss:    1.1043 validation accuracy :0.5332
# Epoch 51, CIFAR-10 Batch 1:  Loss:    1.0898 validation accuracy :0.5386
# Epoch 52, CIFAR-10 Batch 1:  Loss:    1.0856 validation accuracy :0.5394
# Epoch 53, CIFAR-10 Batch 1:  Loss:    1.0781 validation accuracy :0.5390
# Epoch 54, CIFAR-10 Batch 1:  Loss:    1.0756 validation accuracy :0.5398
# Epoch 55, CIFAR-10 Batch 1:  Loss:    1.0703 validation accuracy :0.5424
# Epoch 56, CIFAR-10 Batch 1:  Loss:    1.0707 validation accuracy :0.5380
# Epoch 57, CIFAR-10 Batch 1:  Loss:    1.0523 validation accuracy :0.5432
# Epoch 58, CIFAR-10 Batch 1:  Loss:    1.0521 validation accuracy :0.5442
# Epoch 59, CIFAR-10 Batch 1:  Loss:    1.0455 validation accuracy :0.5424
# Epoch 60, CIFAR-10 Batch 1:  Loss:    1.0424 validation accuracy :0.5448
# Epoch 61, CIFAR-10 Batch 1:  Loss:    1.0363 validation accuracy :0.5442
# Epoch 62, CIFAR-10 Batch 1:  Loss:    1.0330 validation accuracy :0.5484
# Epoch 63, CIFAR-10 Batch 1:  Loss:    1.0284 validation accuracy :0.5514
# Epoch 64, CIFAR-10 Batch 1:  Loss:    1.0133 validation accuracy :0.5468
# Epoch 65, CIFAR-10 Batch 1:  Loss:    1.0126 validation accuracy :0.5466
# Epoch 66, CIFAR-10 Batch 1:  Loss:    1.0106 validation accuracy :0.5512
# Epoch 67, CIFAR-10 Batch 1:  Loss:    1.0065 validation accuracy :0.5510
# Epoch 68, CIFAR-10 Batch 1:  Loss:    1.0056 validation accuracy :0.5508
# Epoch 69, CIFAR-10 Batch 1:  Loss:    0.9984 validation accuracy :0.5556
# Epoch 70, CIFAR-10 Batch 1:  Loss:    1.0020 validation accuracy :0.5480
# Epoch 71, CIFAR-10 Batch 1:  Loss:    0.9953 validation accuracy :0.5464
# Epoch 72, CIFAR-10 Batch 1:  Loss:    0.9850 validation accuracy :0.5510
# Epoch 73, CIFAR-10 Batch 1:  Loss:    0.9788 validation accuracy :0.5530
# Epoch 74, CIFAR-10 Batch 1:  Loss:    0.9768 validation accuracy :0.5506
# Epoch 75, CIFAR-10 Batch 1:  Loss:    0.9729 validation accuracy :0.5534
# Epoch 76, CIFAR-10 Batch 1:  Loss:    0.9718 validation accuracy :0.5544
# Epoch 77, CIFAR-10 Batch 1:  Loss:    0.9728 validation accuracy :0.5530
# Epoch 78, CIFAR-10 Batch 1:  Loss:    0.9650 validation accuracy :0.5520
# Epoch 79, CIFAR-10 Batch 1:  Loss:    0.9624 validation accuracy :0.5564
# Epoch 80, CIFAR-10 Batch 1:  Loss:    0.9525 validation accuracy :0.5576
# Epoch 81, CIFAR-10 Batch 1:  Loss:    0.9526 validation accuracy :0.5570
# Epoch 82, CIFAR-10 Batch 1:  Loss:    0.9498 validation accuracy :0.5578
# Epoch 83, CIFAR-10 Batch 1:  Loss:    0.9471 validation accuracy :0.5554
# Epoch 84, CIFAR-10 Batch 1:  Loss:    0.9432 validation accuracy :0.5590
# Epoch 85, CIFAR-10 Batch 1:  Loss:    0.9483 validation accuracy :0.5584
# Epoch 86, CIFAR-10 Batch 1:  Loss:    0.9358 validation accuracy :0.5592
# Epoch 87, CIFAR-10 Batch 1:  Loss:    0.9315 validation accuracy :0.5594
# Epoch 88, CIFAR-10 Batch 1:  Loss:    0.9293 validation accuracy :0.5612
# Epoch 89, CIFAR-10 Batch 1:  Loss:    0.9267 validation accuracy :0.5586
# Epoch 90, CIFAR-10 Batch 1:  Loss:    0.9208 validation accuracy :0.5596
# Epoch 91, CIFAR-10 Batch 1:  Loss:    0.9228 validation accuracy :0.5596
# Epoch 92, CIFAR-10 Batch 1:  Loss:    0.9189 validation accuracy :0.5610
# Epoch 93, CIFAR-10 Batch 1:  Loss:    0.9173 validation accuracy :0.5606
# Epoch 94, CIFAR-10 Batch 1:  Loss:    0.9132 validation accuracy :0.5608
# Epoch 95, CIFAR-10 Batch 1:  Loss:    0.9023 validation accuracy :0.5568
# Epoch 96, CIFAR-10 Batch 1:  Loss:    0.9086 validation accuracy :0.5584
# Epoch 97, CIFAR-10 Batch 1:  Loss:    0.9048 validation accuracy :0.5640
# Epoch 98, CIFAR-10 Batch 1:  Loss:    0.8940 validation accuracy :0.5626
# Epoch 99, CIFAR-10 Batch 1:  Loss:    0.8995 validation accuracy :0.5608
# Epoch 100, CIFAR-10 Batch 1:  Loss:    0.8902 validation accuracy :0.5620

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:    2.2230 validation accuracy :0.1868
# Epoch  1, CIFAR-10 Batch 2:  Loss:    2.1820 validation accuracy :0.2064
# Epoch  1, CIFAR-10 Batch 3:  Loss:    2.0139 validation accuracy :0.2982
# Epoch  1, CIFAR-10 Batch 4:  Loss:    1.8817 validation accuracy :0.3208
# Epoch  1, CIFAR-10 Batch 5:  Loss:    1.9167 validation accuracy :0.3282
# Epoch  2, CIFAR-10 Batch 1:  Loss:    1.9078 validation accuracy :0.3464
# Epoch  2, CIFAR-10 Batch 2:  Loss:    1.7893 validation accuracy :0.3594
# Epoch  2, CIFAR-10 Batch 3:  Loss:    1.7179 validation accuracy :0.3762
# Epoch  2, CIFAR-10 Batch 4:  Loss:    1.6339 validation accuracy :0.3904
# Epoch  2, CIFAR-10 Batch 5:  Loss:    1.7075 validation accuracy :0.4042
# Epoch  3, CIFAR-10 Batch 1:  Loss:    1.7194 validation accuracy :0.4184
# Epoch  3, CIFAR-10 Batch 2:  Loss:    1.6014 validation accuracy :0.4280
# Epoch  3, CIFAR-10 Batch 3:  Loss:    1.5226 validation accuracy :0.4526
# Epoch  3, CIFAR-10 Batch 4:  Loss:    1.4642 validation accuracy :0.4584
# Epoch  3, CIFAR-10 Batch 5:  Loss:    1.5378 validation accuracy :0.4714
# Epoch  4, CIFAR-10 Batch 1:  Loss:    1.5661 validation accuracy :0.4742
# Epoch  4, CIFAR-10 Batch 2:  Loss:    1.4599 validation accuracy :0.4732
# Epoch  4, CIFAR-10 Batch 3:  Loss:    1.4204 validation accuracy :0.4904
# Epoch  4, CIFAR-10 Batch 4:  Loss:    1.3589 validation accuracy :0.4868
# Epoch  4, CIFAR-10 Batch 5:  Loss:    1.4614 validation accuracy :0.4986
# Epoch  5, CIFAR-10 Batch 1:  Loss:    1.4767 validation accuracy :0.5026
# Epoch  5, CIFAR-10 Batch 2:  Loss:    1.3598 validation accuracy :0.5082
# Epoch  5, CIFAR-10 Batch 3:  Loss:    1.3583 validation accuracy :0.5090
# Epoch  5, CIFAR-10 Batch 4:  Loss:    1.3006 validation accuracy :0.5112
# Epoch  5, CIFAR-10 Batch 5:  Loss:    1.4248 validation accuracy :0.5156
# Epoch  6, CIFAR-10 Batch 1:  Loss:    1.4342 validation accuracy :0.5146
# Epoch  6, CIFAR-10 Batch 2:  Loss:    1.3498 validation accuracy :0.5080
# Epoch  6, CIFAR-10 Batch 3:  Loss:    1.3203 validation accuracy :0.5206
# Epoch  6, CIFAR-10 Batch 4:  Loss:    1.2577 validation accuracy :0.5220
# Epoch  6, CIFAR-10 Batch 5:  Loss:    1.3850 validation accuracy :0.5230
# Epoch  7, CIFAR-10 Batch 1:  Loss:    1.4022 validation accuracy :0.5238
# Epoch  7, CIFAR-10 Batch 2:  Loss:    1.3230 validation accuracy :0.5146
# Epoch  7, CIFAR-10 Batch 3:  Loss:    1.2912 validation accuracy :0.5270
# Epoch  7, CIFAR-10 Batch 4:  Loss:    1.2491 validation accuracy :0.5292
# Epoch  7, CIFAR-10 Batch 5:  Loss:    1.3636 validation accuracy :0.5292
# Epoch  8, CIFAR-10 Batch 1:  Loss:    1.3779 validation accuracy :0.5294
# Epoch  8, CIFAR-10 Batch 2:  Loss:    1.2991 validation accuracy :0.5248
# Epoch  8, CIFAR-10 Batch 3:  Loss:    1.2759 validation accuracy :0.5278
# Epoch  8, CIFAR-10 Batch 4:  Loss:    1.2188 validation accuracy :0.5404
# Epoch  8, CIFAR-10 Batch 5:  Loss:    1.3333 validation accuracy :0.5318
# Epoch  9, CIFAR-10 Batch 1:  Loss:    1.3467 validation accuracy :0.5376
# Epoch  9, CIFAR-10 Batch 2:  Loss:    1.2698 validation accuracy :0.5340
# Epoch  9, CIFAR-10 Batch 3:  Loss:    1.2322 validation accuracy :0.5392
# Epoch  9, CIFAR-10 Batch 4:  Loss:    1.1992 validation accuracy :0.5438
# Epoch  9, CIFAR-10 Batch 5:  Loss:    1.3163 validation accuracy :0.5348
# Epoch 10, CIFAR-10 Batch 1:  Loss:    1.3257 validation accuracy :0.5434
# Epoch 10, CIFAR-10 Batch 2:  Loss:    1.2571 validation accuracy :0.5292
# Epoch 10, CIFAR-10 Batch 3:  Loss:    1.2100 validation accuracy :0.5428
# Epoch 10, CIFAR-10 Batch 4:  Loss:    1.1769 validation accuracy :0.5506
# Epoch 10, CIFAR-10 Batch 5:  Loss:    1.3071 validation accuracy :0.5416
# Epoch 11, CIFAR-10 Batch 1:  Loss:    1.3054 validation accuracy :0.5440
# Epoch 11, CIFAR-10 Batch 2:  Loss:    1.2380 validation accuracy :0.5414
# Epoch 11, CIFAR-10 Batch 3:  Loss:    1.2082 validation accuracy :0.5458
# Epoch 11, CIFAR-10 Batch 4:  Loss:    1.1549 validation accuracy :0.5494
# Epoch 11, CIFAR-10 Batch 5:  Loss:    1.2833 validation accuracy :0.5468
# Epoch 12, CIFAR-10 Batch 1:  Loss:    1.3116 validation accuracy :0.5502
# Epoch 12, CIFAR-10 Batch 2:  Loss:    1.2331 validation accuracy :0.5344
# Epoch 12, CIFAR-10 Batch 3:  Loss:    1.1841 validation accuracy :0.5504
# Epoch 12, CIFAR-10 Batch 4:  Loss:    1.1488 validation accuracy :0.5536
# Epoch 12, CIFAR-10 Batch 5:  Loss:    1.2686 validation accuracy :0.5500
# Epoch 13, CIFAR-10 Batch 1:  Loss:    1.2998 validation accuracy :0.5520
# Epoch 13, CIFAR-10 Batch 2:  Loss:    1.2273 validation accuracy :0.5408
# Epoch 13, CIFAR-10 Batch 3:  Loss:    1.1666 validation accuracy :0.5484
# Epoch 13, CIFAR-10 Batch 4:  Loss:    1.1300 validation accuracy :0.5558
# Epoch 13, CIFAR-10 Batch 5:  Loss:    1.2626 validation accuracy :0.5500
# Epoch 14, CIFAR-10 Batch 1:  Loss:    1.2882 validation accuracy :0.5508
# Epoch 14, CIFAR-10 Batch 2:  Loss:    1.2175 validation accuracy :0.5444
# Epoch 14, CIFAR-10 Batch 3:  Loss:    1.1567 validation accuracy :0.5510
# Epoch 14, CIFAR-10 Batch 4:  Loss:    1.1335 validation accuracy :0.5600
# Epoch 14, CIFAR-10 Batch 5:  Loss:    1.2503 validation accuracy :0.5572
# Epoch 15, CIFAR-10 Batch 1:  Loss:    1.2856 validation accuracy :0.5550
# Epoch 15, CIFAR-10 Batch 2:  Loss:    1.2048 validation accuracy :0.5488
# Epoch 15, CIFAR-10 Batch 3:  Loss:    1.1507 validation accuracy :0.5532
# Epoch 15, CIFAR-10 Batch 4:  Loss:    1.1194 validation accuracy :0.5582
# Epoch 15, CIFAR-10 Batch 5:  Loss:    1.2411 validation accuracy :0.5558
# Epoch 16, CIFAR-10 Batch 1:  Loss:    1.2781 validation accuracy :0.5558
# Epoch 16, CIFAR-10 Batch 2:  Loss:    1.1981 validation accuracy :0.5492
# Epoch 16, CIFAR-10 Batch 3:  Loss:    1.1417 validation accuracy :0.5540
# Epoch 16, CIFAR-10 Batch 4:  Loss:    1.1116 validation accuracy :0.5612
# Epoch 16, CIFAR-10 Batch 5:  Loss:    1.2258 validation accuracy :0.5596
# Epoch 17, CIFAR-10 Batch 1:  Loss:    1.2782 validation accuracy :0.5574
# Epoch 17, CIFAR-10 Batch 2:  Loss:    1.1994 validation accuracy :0.5480
# Epoch 17, CIFAR-10 Batch 3:  Loss:    1.1446 validation accuracy :0.5566
# Epoch 17, CIFAR-10 Batch 4:  Loss:    1.0980 validation accuracy :0.5590
# Epoch 17, CIFAR-10 Batch 5:  Loss:    1.2159 validation accuracy :0.5582
# Epoch 18, CIFAR-10 Batch 1:  Loss:    1.2728 validation accuracy :0.5552
# Epoch 18, CIFAR-10 Batch 2:  Loss:    1.1822 validation accuracy :0.5530
# Epoch 18, CIFAR-10 Batch 3:  Loss:    1.1294 validation accuracy :0.5604
# Epoch 18, CIFAR-10 Batch 4:  Loss:    1.0900 validation accuracy :0.5614
# Epoch 18, CIFAR-10 Batch 5:  Loss:    1.2080 validation accuracy :0.5592
# Epoch 19, CIFAR-10 Batch 1:  Loss:    1.2692 validation accuracy :0.5552
# Epoch 19, CIFAR-10 Batch 2:  Loss:    1.1978 validation accuracy :0.5490
# Epoch 19, CIFAR-10 Batch 3:  Loss:    1.1241 validation accuracy :0.5610
# Epoch 19, CIFAR-10 Batch 4:  Loss:    1.0887 validation accuracy :0.5624
# Epoch 19, CIFAR-10 Batch 5:  Loss:    1.1960 validation accuracy :0.5652
# Epoch 20, CIFAR-10 Batch 1:  Loss:    1.2562 validation accuracy :0.5616
# Epoch 20, CIFAR-10 Batch 2:  Loss:    1.1679 validation accuracy :0.5580
# Epoch 20, CIFAR-10 Batch 3:  Loss:    1.1195 validation accuracy :0.5570
# Epoch 20, CIFAR-10 Batch 4:  Loss:    1.0863 validation accuracy :0.5604
# Epoch 20, CIFAR-10 Batch 5:  Loss:    1.1838 validation accuracy :0.5668
# Epoch 21, CIFAR-10 Batch 1:  Loss:    1.2588 validation accuracy :0.5578
# Epoch 21, CIFAR-10 Batch 2:  Loss:    1.1793 validation accuracy :0.5554
# Epoch 21, CIFAR-10 Batch 3:  Loss:    1.1045 validation accuracy :0.5636
# Epoch 21, CIFAR-10 Batch 4:  Loss:    1.0766 validation accuracy :0.5676
# Epoch 21, CIFAR-10 Batch 5:  Loss:    1.1795 validation accuracy :0.5660
# Epoch 22, CIFAR-10 Batch 1:  Loss:    1.2500 validation accuracy :0.5636
# Epoch 22, CIFAR-10 Batch 2:  Loss:    1.1583 validation accuracy :0.5604
# Epoch 22, CIFAR-10 Batch 3:  Loss:    1.1006 validation accuracy :0.5664
# Epoch 22, CIFAR-10 Batch 4:  Loss:    1.0702 validation accuracy :0.5672
# Epoch 22, CIFAR-10 Batch 5:  Loss:    1.1757 validation accuracy :0.5634
# Epoch 23, CIFAR-10 Batch 1:  Loss:    1.2400 validation accuracy :0.5650
# Epoch 23, CIFAR-10 Batch 2:  Loss:    1.1670 validation accuracy :0.5576
# Epoch 23, CIFAR-10 Batch 3:  Loss:    1.1033 validation accuracy :0.5610
# Epoch 23, CIFAR-10 Batch 4:  Loss:    1.0661 validation accuracy :0.5696
# Epoch 23, CIFAR-10 Batch 5:  Loss:    1.1668 validation accuracy :0.5658
# Epoch 24, CIFAR-10 Batch 1:  Loss:    1.2343 validation accuracy :0.5658
# Epoch 24, CIFAR-10 Batch 2:  Loss:    1.1615 validation accuracy :0.5626
# Epoch 24, CIFAR-10 Batch 3:  Loss:    1.1090 validation accuracy :0.5608
# Epoch 24, CIFAR-10 Batch 4:  Loss:    1.0595 validation accuracy :0.5706
# Epoch 24, CIFAR-10 Batch 5:  Loss:    1.1675 validation accuracy :0.5650
# Epoch 25, CIFAR-10 Batch 1:  Loss:    1.2311 validation accuracy :0.5654
# Epoch 25, CIFAR-10 Batch 2:  Loss:    1.1559 validation accuracy :0.5568
# Epoch 25, CIFAR-10 Batch 3:  Loss:    1.0876 validation accuracy :0.5666
# Epoch 25, CIFAR-10 Batch 4:  Loss:    1.0597 validation accuracy :0.5698
# Epoch 25, CIFAR-10 Batch 5:  Loss:    1.1521 validation accuracy :0.5698
# Epoch 26, CIFAR-10 Batch 1:  Loss:    1.2223 validation accuracy :0.5628
# Epoch 26, CIFAR-10 Batch 2:  Loss:    1.1487 validation accuracy :0.5618
# Epoch 26, CIFAR-10 Batch 3:  Loss:    1.0893 validation accuracy :0.5640
# Epoch 26, CIFAR-10 Batch 4:  Loss:    1.0552 validation accuracy :0.5722
# Epoch 26, CIFAR-10 Batch 5:  Loss:    1.1429 validation accuracy :0.5694
# Epoch 27, CIFAR-10 Batch 1:  Loss:    1.2205 validation accuracy :0.5654
# Epoch 27, CIFAR-10 Batch 2:  Loss:    1.1290 validation accuracy :0.5636
# Epoch 27, CIFAR-10 Batch 3:  Loss:    1.0914 validation accuracy :0.5660
# Epoch 27, CIFAR-10 Batch 4:  Loss:    1.0473 validation accuracy :0.5692
# Epoch 27, CIFAR-10 Batch 5:  Loss:    1.1395 validation accuracy :0.5672
# Epoch 28, CIFAR-10 Batch 1:  Loss:    1.2192 validation accuracy :0.5680
# Epoch 28, CIFAR-10 Batch 2:  Loss:    1.1304 validation accuracy :0.5646
# Epoch 28, CIFAR-10 Batch 3:  Loss:    1.0837 validation accuracy :0.5638
# Epoch 28, CIFAR-10 Batch 4:  Loss:    1.0439 validation accuracy :0.5710
# Epoch 28, CIFAR-10 Batch 5:  Loss:    1.1304 validation accuracy :0.5682
# Epoch 29, CIFAR-10 Batch 1:  Loss:    1.2109 validation accuracy :0.5680
# Epoch 29, CIFAR-10 Batch 2:  Loss:    1.1263 validation accuracy :0.5632
# Epoch 29, CIFAR-10 Batch 3:  Loss:    1.0906 validation accuracy :0.5652
# Epoch 29, CIFAR-10 Batch 4:  Loss:    1.0366 validation accuracy :0.5712
# Epoch 29, CIFAR-10 Batch 5:  Loss:    1.1315 validation accuracy :0.5698
# Epoch 30, CIFAR-10 Batch 1:  Loss:    1.2049 validation accuracy :0.5688
# Epoch 30, CIFAR-10 Batch 2:  Loss:    1.1154 validation accuracy :0.5682
# Epoch 30, CIFAR-10 Batch 3:  Loss:    1.0750 validation accuracy :0.5702
# Epoch 30, CIFAR-10 Batch 4:  Loss:    1.0356 validation accuracy :0.5724
# Epoch 30, CIFAR-10 Batch 5:  Loss:    1.1169 validation accuracy :0.5712
# Epoch 31, CIFAR-10 Batch 1:  Loss:    1.2030 validation accuracy :0.5716
# Epoch 31, CIFAR-10 Batch 2:  Loss:    1.1176 validation accuracy :0.5666
# Epoch 31, CIFAR-10 Batch 3:  Loss:    1.0707 validation accuracy :0.5692
# Epoch 31, CIFAR-10 Batch 4:  Loss:    1.0312 validation accuracy :0.5756
# Epoch 31, CIFAR-10 Batch 5:  Loss:    1.1070 validation accuracy :0.5754
# Epoch 32, CIFAR-10 Batch 1:  Loss:    1.1966 validation accuracy :0.5680
# Epoch 32, CIFAR-10 Batch 2:  Loss:    1.1087 validation accuracy :0.5664
# Epoch 32, CIFAR-10 Batch 3:  Loss:    1.0651 validation accuracy :0.5734
# Epoch 32, CIFAR-10 Batch 4:  Loss:    1.0267 validation accuracy :0.5710
# Epoch 32, CIFAR-10 Batch 5:  Loss:    1.1039 validation accuracy :0.5774
# Epoch 33, CIFAR-10 Batch 1:  Loss:    1.1963 validation accuracy :0.5704
# Epoch 33, CIFAR-10 Batch 2:  Loss:    1.0983 validation accuracy :0.5658
# Epoch 33, CIFAR-10 Batch 3:  Loss:    1.0636 validation accuracy :0.5722
# Epoch 33, CIFAR-10 Batch 4:  Loss:    1.0205 validation accuracy :0.5760
# Epoch 33, CIFAR-10 Batch 5:  Loss:    1.0869 validation accuracy :0.5762
# Epoch 34, CIFAR-10 Batch 1:  Loss:    1.2008 validation accuracy :0.5612
# Epoch 34, CIFAR-10 Batch 2:  Loss:    1.1078 validation accuracy :0.5656
# Epoch 34, CIFAR-10 Batch 3:  Loss:    1.0625 validation accuracy :0.5764
# Epoch 34, CIFAR-10 Batch 4:  Loss:    1.0203 validation accuracy :0.5754
# Epoch 34, CIFAR-10 Batch 5:  Loss:    1.0839 validation accuracy :0.5752
# Epoch 35, CIFAR-10 Batch 1:  Loss:    1.1885 validation accuracy :0.5706
# Epoch 35, CIFAR-10 Batch 2:  Loss:    1.1048 validation accuracy :0.5676
# Epoch 35, CIFAR-10 Batch 3:  Loss:    1.0575 validation accuracy :0.5744
# Epoch 35, CIFAR-10 Batch 4:  Loss:    1.0194 validation accuracy :0.5758
# Epoch 35, CIFAR-10 Batch 5:  Loss:    1.0783 validation accuracy :0.5774
# Epoch 36, CIFAR-10 Batch 1:  Loss:    1.1851 validation accuracy :0.5730
# Epoch 36, CIFAR-10 Batch 2:  Loss:    1.0834 validation accuracy :0.5714
# Epoch 36, CIFAR-10 Batch 3:  Loss:    1.0624 validation accuracy :0.5726
# Epoch 36, CIFAR-10 Batch 4:  Loss:    1.0133 validation accuracy :0.5780
# Epoch 36, CIFAR-10 Batch 5:  Loss:    1.0704 validation accuracy :0.5822
# Epoch 37, CIFAR-10 Batch 1:  Loss:    1.1759 validation accuracy :0.5752
# Epoch 37, CIFAR-10 Batch 2:  Loss:    1.0837 validation accuracy :0.5742
# Epoch 37, CIFAR-10 Batch 3:  Loss:    1.0686 validation accuracy :0.5736
# Epoch 37, CIFAR-10 Batch 4:  Loss:    1.0103 validation accuracy :0.5778
# Epoch 37, CIFAR-10 Batch 5:  Loss:    1.0671 validation accuracy :0.5842
# Epoch 38, CIFAR-10 Batch 1:  Loss:    1.1793 validation accuracy :0.5796
# Epoch 38, CIFAR-10 Batch 2:  Loss:    1.0660 validation accuracy :0.5768
# Epoch 38, CIFAR-10 Batch 3:  Loss:    1.0611 validation accuracy :0.5754
# Epoch 38, CIFAR-10 Batch 4:  Loss:    0.9951 validation accuracy :0.5774
# Epoch 38, CIFAR-10 Batch 5:  Loss:    1.0534 validation accuracy :0.5768
# Epoch 39, CIFAR-10 Batch 1:  Loss:    1.1756 validation accuracy :0.5754
# Epoch 39, CIFAR-10 Batch 2:  Loss:    1.0765 validation accuracy :0.5758
# Epoch 39, CIFAR-10 Batch 3:  Loss:    1.0658 validation accuracy :0.5754
# Epoch 39, CIFAR-10 Batch 4:  Loss:    0.9992 validation accuracy :0.5766
# Epoch 39, CIFAR-10 Batch 5:  Loss:    1.0512 validation accuracy :0.5826
# Epoch 40, CIFAR-10 Batch 1:  Loss:    1.1718 validation accuracy :0.5760
# Epoch 40, CIFAR-10 Batch 2:  Loss:    1.0757 validation accuracy :0.5734
# Epoch 40, CIFAR-10 Batch 3:  Loss:    1.0567 validation accuracy :0.5788
# Epoch 40, CIFAR-10 Batch 4:  Loss:    1.0010 validation accuracy :0.5828
# Epoch 40, CIFAR-10 Batch 5:  Loss:    1.0473 validation accuracy :0.5834
# Epoch 41, CIFAR-10 Batch 1:  Loss:    1.1678 validation accuracy :0.5774
# Epoch 41, CIFAR-10 Batch 2:  Loss:    1.0684 validation accuracy :0.5710
# Epoch 41, CIFAR-10 Batch 3:  Loss:    1.0606 validation accuracy :0.5756
# Epoch 41, CIFAR-10 Batch 4:  Loss:    0.9880 validation accuracy :0.5796
# Epoch 41, CIFAR-10 Batch 5:  Loss:    1.0541 validation accuracy :0.5812
# Epoch 42, CIFAR-10 Batch 1:  Loss:    1.1617 validation accuracy :0.5788
# Epoch 42, CIFAR-10 Batch 2:  Loss:    1.0638 validation accuracy :0.5770
# Epoch 42, CIFAR-10 Batch 3:  Loss:    1.0596 validation accuracy :0.5772
# Epoch 42, CIFAR-10 Batch 4:  Loss:    0.9945 validation accuracy :0.5828
# Epoch 42, CIFAR-10 Batch 5:  Loss:    1.0434 validation accuracy :0.5876
# Epoch 43, CIFAR-10 Batch 1:  Loss:    1.1563 validation accuracy :0.5792
# Epoch 43, CIFAR-10 Batch 2:  Loss:    1.0549 validation accuracy :0.5790
# Epoch 43, CIFAR-10 Batch 3:  Loss:    1.0560 validation accuracy :0.5792
# Epoch 43, CIFAR-10 Batch 4:  Loss:    0.9899 validation accuracy :0.5782
# Epoch 43, CIFAR-10 Batch 5:  Loss:    1.0422 validation accuracy :0.5850
# Epoch 44, CIFAR-10 Batch 1:  Loss:    1.1570 validation accuracy :0.5750
# Epoch 44, CIFAR-10 Batch 2:  Loss:    1.0653 validation accuracy :0.5688
# Epoch 44, CIFAR-10 Batch 3:  Loss:    1.0519 validation accuracy :0.5768
# Epoch 44, CIFAR-10 Batch 4:  Loss:    0.9923 validation accuracy :0.5816
# Epoch 44, CIFAR-10 Batch 5:  Loss:    1.0375 validation accuracy :0.5866
# Epoch 45, CIFAR-10 Batch 1:  Loss:    1.1477 validation accuracy :0.5812
# Epoch 45, CIFAR-10 Batch 2:  Loss:    1.0435 validation accuracy :0.5762
# Epoch 45, CIFAR-10 Batch 3:  Loss:    1.0634 validation accuracy :0.5718
# Epoch 45, CIFAR-10 Batch 4:  Loss:    0.9894 validation accuracy :0.5818
# Epoch 45, CIFAR-10 Batch 5:  Loss:    1.0353 validation accuracy :0.5834
# Epoch 46, CIFAR-10 Batch 1:  Loss:    1.1428 validation accuracy :0.5842
# Epoch 46, CIFAR-10 Batch 2:  Loss:    1.0359 validation accuracy :0.5798
# Epoch 46, CIFAR-10 Batch 3:  Loss:    1.0569 validation accuracy :0.5756
# Epoch 46, CIFAR-10 Batch 4:  Loss:    0.9874 validation accuracy :0.5844
# Epoch 46, CIFAR-10 Batch 5:  Loss:    1.0313 validation accuracy :0.5850
# Epoch 47, CIFAR-10 Batch 1:  Loss:    1.1457 validation accuracy :0.5804
# Epoch 47, CIFAR-10 Batch 2:  Loss:    1.0340 validation accuracy :0.5778
# Epoch 47, CIFAR-10 Batch 3:  Loss:    1.0481 validation accuracy :0.5756
# Epoch 47, CIFAR-10 Batch 4:  Loss:    0.9907 validation accuracy :0.5804
# Epoch 47, CIFAR-10 Batch 5:  Loss:    1.0202 validation accuracy :0.5892
# Epoch 48, CIFAR-10 Batch 1:  Loss:    1.1346 validation accuracy :0.5876
# Epoch 48, CIFAR-10 Batch 2:  Loss:    1.0302 validation accuracy :0.5822
# Epoch 48, CIFAR-10 Batch 3:  Loss:    1.0423 validation accuracy :0.5788
# Epoch 48, CIFAR-10 Batch 4:  Loss:    0.9888 validation accuracy :0.5890
# Epoch 48, CIFAR-10 Batch 5:  Loss:    1.0185 validation accuracy :0.5896
# Epoch 49, CIFAR-10 Batch 1:  Loss:    1.1348 validation accuracy :0.5858
# Epoch 49, CIFAR-10 Batch 2:  Loss:    1.0185 validation accuracy :0.5790
# Epoch 49, CIFAR-10 Batch 3:  Loss:    1.0590 validation accuracy :0.5730
# Epoch 49, CIFAR-10 Batch 4:  Loss:    0.9867 validation accuracy :0.5846
# Epoch 49, CIFAR-10 Batch 5:  Loss:    1.0105 validation accuracy :0.5910
# Epoch 50, CIFAR-10 Batch 1:  Loss:    1.1297 validation accuracy :0.5886
# Epoch 50, CIFAR-10 Batch 2:  Loss:    1.0190 validation accuracy :0.5826
# Epoch 50, CIFAR-10 Batch 3:  Loss:    1.0521 validation accuracy :0.5764
# Epoch 50, CIFAR-10 Batch 4:  Loss:    0.9982 validation accuracy :0.5782
# Epoch 50, CIFAR-10 Batch 5:  Loss:    1.0049 validation accuracy :0.5952
# Epoch 51, CIFAR-10 Batch 1:  Loss:    1.1177 validation accuracy :0.5906
# Epoch 51, CIFAR-10 Batch 2:  Loss:    1.0079 validation accuracy :0.5876
# Epoch 51, CIFAR-10 Batch 3:  Loss:    1.0301 validation accuracy :0.5858
# Epoch 51, CIFAR-10 Batch 4:  Loss:    0.9913 validation accuracy :0.5800
# Epoch 51, CIFAR-10 Batch 5:  Loss:    0.9922 validation accuracy :0.5908
# Epoch 52, CIFAR-10 Batch 1:  Loss:    1.1192 validation accuracy :0.5814
# Epoch 52, CIFAR-10 Batch 2:  Loss:    1.0009 validation accuracy :0.5840
# Epoch 52, CIFAR-10 Batch 3:  Loss:    1.0433 validation accuracy :0.5806
# Epoch 52, CIFAR-10 Batch 4:  Loss:    0.9905 validation accuracy :0.5808
# Epoch 52, CIFAR-10 Batch 5:  Loss:    0.9895 validation accuracy :0.5924
# Epoch 53, CIFAR-10 Batch 1:  Loss:    1.1040 validation accuracy :0.5932
# Epoch 53, CIFAR-10 Batch 2:  Loss:    0.9963 validation accuracy :0.5894
# Epoch 53, CIFAR-10 Batch 3:  Loss:    1.0231 validation accuracy :0.5848
# Epoch 53, CIFAR-10 Batch 4:  Loss:    0.9816 validation accuracy :0.5836
# Epoch 53, CIFAR-10 Batch 5:  Loss:    0.9850 validation accuracy :0.5976
# Epoch 54, CIFAR-10 Batch 1:  Loss:    1.0998 validation accuracy :0.5898
# Epoch 54, CIFAR-10 Batch 2:  Loss:    0.9839 validation accuracy :0.5944
# Epoch 54, CIFAR-10 Batch 3:  Loss:    1.0292 validation accuracy :0.5824
# Epoch 54, CIFAR-10 Batch 4:  Loss:    0.9782 validation accuracy :0.5888
# Epoch 54, CIFAR-10 Batch 5:  Loss:    0.9846 validation accuracy :0.5978
# Epoch 55, CIFAR-10 Batch 1:  Loss:    1.0921 validation accuracy :0.5956
# Epoch 55, CIFAR-10 Batch 2:  Loss:    0.9722 validation accuracy :0.5944
# Epoch 55, CIFAR-10 Batch 3:  Loss:    1.0113 validation accuracy :0.5876
# Epoch 55, CIFAR-10 Batch 4:  Loss:    0.9909 validation accuracy :0.5900
# Epoch 55, CIFAR-10 Batch 5:  Loss:    0.9756 validation accuracy :0.6000
# Epoch 56, CIFAR-10 Batch 1:  Loss:    1.0922 validation accuracy :0.5870
# Epoch 56, CIFAR-10 Batch 2:  Loss:    0.9939 validation accuracy :0.5922
# Epoch 56, CIFAR-10 Batch 3:  Loss:    1.0203 validation accuracy :0.5864
# Epoch 56, CIFAR-10 Batch 4:  Loss:    0.9673 validation accuracy :0.5876
# Epoch 56, CIFAR-10 Batch 5:  Loss:    0.9734 validation accuracy :0.6016
# Epoch 57, CIFAR-10 Batch 1:  Loss:    1.0834 validation accuracy :0.5924
# Epoch 57, CIFAR-10 Batch 2:  Loss:    0.9726 validation accuracy :0.5932
# Epoch 57, CIFAR-10 Batch 3:  Loss:    0.9860 validation accuracy :0.5946
# Epoch 57, CIFAR-10 Batch 4:  Loss:    0.9773 validation accuracy :0.5976
# Epoch 57, CIFAR-10 Batch 5:  Loss:    0.9817 validation accuracy :0.6060
# Epoch 58, CIFAR-10 Batch 1:  Loss:    1.0876 validation accuracy :0.5864
# Epoch 58, CIFAR-10 Batch 2:  Loss:    0.9844 validation accuracy :0.5940
# Epoch 58, CIFAR-10 Batch 3:  Loss:    0.9882 validation accuracy :0.5940
# Epoch 58, CIFAR-10 Batch 4:  Loss:    0.9784 validation accuracy :0.5888
# Epoch 58, CIFAR-10 Batch 5:  Loss:    0.9737 validation accuracy :0.6028
# Epoch 59, CIFAR-10 Batch 1:  Loss:    1.0761 validation accuracy :0.5982
# Epoch 59, CIFAR-10 Batch 2:  Loss:    0.9651 validation accuracy :0.6004
# Epoch 59, CIFAR-10 Batch 3:  Loss:    0.9897 validation accuracy :0.5918
# Epoch 59, CIFAR-10 Batch 4:  Loss:    0.9761 validation accuracy :0.5904
# Epoch 59, CIFAR-10 Batch 5:  Loss:    0.9811 validation accuracy :0.6050
# Epoch 60, CIFAR-10 Batch 1:  Loss:    1.0780 validation accuracy :0.5944
# Epoch 60, CIFAR-10 Batch 2:  Loss:    0.9640 validation accuracy :0.5998
# Epoch 60, CIFAR-10 Batch 3:  Loss:    0.9677 validation accuracy :0.6010
# Epoch 60, CIFAR-10 Batch 4:  Loss:    0.9782 validation accuracy :0.5892
# Epoch 60, CIFAR-10 Batch 5:  Loss:    0.9678 validation accuracy :0.6092
# Epoch 61, CIFAR-10 Batch 1:  Loss:    1.0737 validation accuracy :0.5966
# Epoch 61, CIFAR-10 Batch 2:  Loss:    0.9636 validation accuracy :0.5984
# Epoch 61, CIFAR-10 Batch 3:  Loss:    0.9625 validation accuracy :0.6010
# Epoch 61, CIFAR-10 Batch 4:  Loss:    0.9708 validation accuracy :0.5950
# Epoch 61, CIFAR-10 Batch 5:  Loss:    0.9640 validation accuracy :0.6164
# Epoch 62, CIFAR-10 Batch 1:  Loss:    1.0745 validation accuracy :0.5964
# Epoch 62, CIFAR-10 Batch 2:  Loss:    0.9515 validation accuracy :0.6084
# Epoch 62, CIFAR-10 Batch 3:  Loss:    0.9532 validation accuracy :0.6054
# Epoch 62, CIFAR-10 Batch 4:  Loss:    0.9579 validation accuracy :0.5984
# Epoch 62, CIFAR-10 Batch 5:  Loss:    0.9576 validation accuracy :0.6120
# Epoch 63, CIFAR-10 Batch 1:  Loss:    1.0619 validation accuracy :0.6074
# Epoch 63, CIFAR-10 Batch 2:  Loss:    0.9525 validation accuracy :0.6092
# Epoch 63, CIFAR-10 Batch 3:  Loss:    0.9593 validation accuracy :0.6078
# Epoch 63, CIFAR-10 Batch 4:  Loss:    0.9706 validation accuracy :0.5924
# Epoch 63, CIFAR-10 Batch 5:  Loss:    0.9606 validation accuracy :0.6158
# Epoch 64, CIFAR-10 Batch 1:  Loss:    1.0626 validation accuracy :0.6048
# Epoch 64, CIFAR-10 Batch 2:  Loss:    0.9544 validation accuracy :0.6118
# Epoch 64, CIFAR-10 Batch 3:  Loss:    0.9486 validation accuracy :0.6080
# Epoch 64, CIFAR-10 Batch 4:  Loss:    0.9597 validation accuracy :0.6044
# Epoch 64, CIFAR-10 Batch 5:  Loss:    0.9572 validation accuracy :0.6094
# Epoch 65, CIFAR-10 Batch 1:  Loss:    1.0724 validation accuracy :0.6022
# Epoch 65, CIFAR-10 Batch 2:  Loss:    0.9468 validation accuracy :0.6086
# Epoch 65, CIFAR-10 Batch 3:  Loss:    0.9540 validation accuracy :0.6082
# Epoch 65, CIFAR-10 Batch 4:  Loss:    0.9521 validation accuracy :0.6032
# Epoch 65, CIFAR-10 Batch 5:  Loss:    0.9465 validation accuracy :0.6168
# Epoch 66, CIFAR-10 Batch 1:  Loss:    1.0587 validation accuracy :0.6042
# Epoch 66, CIFAR-10 Batch 2:  Loss:    0.9354 validation accuracy :0.6138
# Epoch 66, CIFAR-10 Batch 3:  Loss:    0.9489 validation accuracy :0.6104
# Epoch 66, CIFAR-10 Batch 4:  Loss:    0.9600 validation accuracy :0.5970
# Epoch 66, CIFAR-10 Batch 5:  Loss:    0.9397 validation accuracy :0.6180
# Epoch 67, CIFAR-10 Batch 1:  Loss:    1.0524 validation accuracy :0.6098
# Epoch 67, CIFAR-10 Batch 2:  Loss:    0.9369 validation accuracy :0.6158
# Epoch 67, CIFAR-10 Batch 3:  Loss:    0.9549 validation accuracy :0.6086
# Epoch 67, CIFAR-10 Batch 4:  Loss:    0.9533 validation accuracy :0.6002
# Epoch 67, CIFAR-10 Batch 5:  Loss:    0.9440 validation accuracy :0.6120
# Epoch 68, CIFAR-10 Batch 1:  Loss:    1.0595 validation accuracy :0.6052
# Epoch 68, CIFAR-10 Batch 2:  Loss:    0.9213 validation accuracy :0.6176
# Epoch 68, CIFAR-10 Batch 3:  Loss:    0.9559 validation accuracy :0.6060
# Epoch 68, CIFAR-10 Batch 4:  Loss:    0.9597 validation accuracy :0.6036
# Epoch 68, CIFAR-10 Batch 5:  Loss:    0.9364 validation accuracy :0.6198
# Epoch 69, CIFAR-10 Batch 1:  Loss:    1.0584 validation accuracy :0.6044
# Epoch 69, CIFAR-10 Batch 2:  Loss:    0.9336 validation accuracy :0.6162
# Epoch 69, CIFAR-10 Batch 3:  Loss:    0.9503 validation accuracy :0.6112
# Epoch 69, CIFAR-10 Batch 4:  Loss:    0.9608 validation accuracy :0.6010
# Epoch 69, CIFAR-10 Batch 5:  Loss:    0.9283 validation accuracy :0.6198
# Epoch 70, CIFAR-10 Batch 1:  Loss:    1.0469 validation accuracy :0.6078
# Epoch 70, CIFAR-10 Batch 2:  Loss:    0.9300 validation accuracy :0.6164
# Epoch 70, CIFAR-10 Batch 3:  Loss:    0.9466 validation accuracy :0.6054
# Epoch 70, CIFAR-10 Batch 4:  Loss:    0.9404 validation accuracy :0.6082
# Epoch 70, CIFAR-10 Batch 5:  Loss:    0.9260 validation accuracy :0.6202
# Epoch 71, CIFAR-10 Batch 1:  Loss:    1.0530 validation accuracy :0.6050
# Epoch 71, CIFAR-10 Batch 2:  Loss:    0.9284 validation accuracy :0.6184
# Epoch 71, CIFAR-10 Batch 3:  Loss:    0.9607 validation accuracy :0.6078
# Epoch 71, CIFAR-10 Batch 4:  Loss:    0.9570 validation accuracy :0.6040
# Epoch 71, CIFAR-10 Batch 5:  Loss:    0.9273 validation accuracy :0.6198
# Epoch 72, CIFAR-10 Batch 1:  Loss:    1.0470 validation accuracy :0.6104
# Epoch 72, CIFAR-10 Batch 2:  Loss:    0.9212 validation accuracy :0.6242
# Epoch 72, CIFAR-10 Batch 3:  Loss:    0.9411 validation accuracy :0.6122
# Epoch 72, CIFAR-10 Batch 4:  Loss:    0.9475 validation accuracy :0.6070
# Epoch 72, CIFAR-10 Batch 5:  Loss:    0.9363 validation accuracy :0.6234
# Epoch 73, CIFAR-10 Batch 1:  Loss:    1.0478 validation accuracy :0.6126
# Epoch 73, CIFAR-10 Batch 2:  Loss:    0.9324 validation accuracy :0.6140
# Epoch 73, CIFAR-10 Batch 3:  Loss:    0.9349 validation accuracy :0.6156
# Epoch 73, CIFAR-10 Batch 4:  Loss:    0.9502 validation accuracy :0.6030
# Epoch 73, CIFAR-10 Batch 5:  Loss:    0.9319 validation accuracy :0.6238
# Epoch 74, CIFAR-10 Batch 1:  Loss:    1.0462 validation accuracy :0.6100
# Epoch 74, CIFAR-10 Batch 2:  Loss:    0.9250 validation accuracy :0.6194
# Epoch 74, CIFAR-10 Batch 3:  Loss:    0.9406 validation accuracy :0.6160
# Epoch 74, CIFAR-10 Batch 4:  Loss:    0.9504 validation accuracy :0.6092
# Epoch 74, CIFAR-10 Batch 5:  Loss:    0.9237 validation accuracy :0.6278
# Epoch 75, CIFAR-10 Batch 1:  Loss:    1.0333 validation accuracy :0.6142
# Epoch 75, CIFAR-10 Batch 2:  Loss:    0.9173 validation accuracy :0.6192
# Epoch 75, CIFAR-10 Batch 3:  Loss:    0.9466 validation accuracy :0.6090
# Epoch 75, CIFAR-10 Batch 4:  Loss:    0.9479 validation accuracy :0.6108
# Epoch 75, CIFAR-10 Batch 5:  Loss:    0.9187 validation accuracy :0.6252
# Epoch 76, CIFAR-10 Batch 1:  Loss:    1.0461 validation accuracy :0.6074
# Epoch 76, CIFAR-10 Batch 2:  Loss:    0.9280 validation accuracy :0.6156
# Epoch 76, CIFAR-10 Batch 3:  Loss:    0.9449 validation accuracy :0.6104
# Epoch 76, CIFAR-10 Batch 4:  Loss:    0.9445 validation accuracy :0.6096
# Epoch 76, CIFAR-10 Batch 5:  Loss:    0.9181 validation accuracy :0.6252
# Epoch 77, CIFAR-10 Batch 1:  Loss:    1.0412 validation accuracy :0.6096
# Epoch 77, CIFAR-10 Batch 2:  Loss:    0.9245 validation accuracy :0.6190
# Epoch 77, CIFAR-10 Batch 3:  Loss:    0.9354 validation accuracy :0.6192
# Epoch 77, CIFAR-10 Batch 4:  Loss:    0.9517 validation accuracy :0.6114
# Epoch 77, CIFAR-10 Batch 5:  Loss:    0.9233 validation accuracy :0.6258
# Epoch 78, CIFAR-10 Batch 1:  Loss:    1.0527 validation accuracy :0.6048
# Epoch 78, CIFAR-10 Batch 2:  Loss:    0.9165 validation accuracy :0.6260
# Epoch 78, CIFAR-10 Batch 3:  Loss:    0.9317 validation accuracy :0.6176
# Epoch 78, CIFAR-10 Batch 4:  Loss:    0.9500 validation accuracy :0.6080
# Epoch 78, CIFAR-10 Batch 5:  Loss:    0.9184 validation accuracy :0.6272
# Epoch 79, CIFAR-10 Batch 1:  Loss:    1.0352 validation accuracy :0.6102
# Epoch 79, CIFAR-10 Batch 2:  Loss:    0.9265 validation accuracy :0.6190
# Epoch 79, CIFAR-10 Batch 3:  Loss:    0.9408 validation accuracy :0.6144
# Epoch 79, CIFAR-10 Batch 4:  Loss:    0.9510 validation accuracy :0.6060
# Epoch 79, CIFAR-10 Batch 5:  Loss:    0.9171 validation accuracy :0.6248
# Epoch 80, CIFAR-10 Batch 1:  Loss:    1.0305 validation accuracy :0.6118
# Epoch 80, CIFAR-10 Batch 2:  Loss:    0.9242 validation accuracy :0.6210
# Epoch 80, CIFAR-10 Batch 3:  Loss:    0.9381 validation accuracy :0.6140
# Epoch 80, CIFAR-10 Batch 4:  Loss:    0.9476 validation accuracy :0.6096
# Epoch 80, CIFAR-10 Batch 5:  Loss:    0.9133 validation accuracy :0.6274
# Epoch 81, CIFAR-10 Batch 1:  Loss:    1.0334 validation accuracy :0.6116
# Epoch 81, CIFAR-10 Batch 2:  Loss:    0.9282 validation accuracy :0.6178
# Epoch 81, CIFAR-10 Batch 3:  Loss:    0.9384 validation accuracy :0.6192
# Epoch 81, CIFAR-10 Batch 4:  Loss:    0.9527 validation accuracy :0.6028
# Epoch 81, CIFAR-10 Batch 5:  Loss:    0.9171 validation accuracy :0.6282
# Epoch 82, CIFAR-10 Batch 1:  Loss:    1.0433 validation accuracy :0.6108
# Epoch 82, CIFAR-10 Batch 2:  Loss:    0.9177 validation accuracy :0.6228
# Epoch 82, CIFAR-10 Batch 3:  Loss:    0.9327 validation accuracy :0.6224
# Epoch 82, CIFAR-10 Batch 4:  Loss:    0.9491 validation accuracy :0.6042
# Epoch 82, CIFAR-10 Batch 5:  Loss:    0.9143 validation accuracy :0.6290
# Epoch 83, CIFAR-10 Batch 1:  Loss:    1.0420 validation accuracy :0.6068
# Epoch 83, CIFAR-10 Batch 2:  Loss:    0.9274 validation accuracy :0.6160
# Epoch 83, CIFAR-10 Batch 3:  Loss:    0.9431 validation accuracy :0.6136
# Epoch 83, CIFAR-10 Batch 4:  Loss:    0.9571 validation accuracy :0.6024
# Epoch 83, CIFAR-10 Batch 5:  Loss:    0.9010 validation accuracy :0.6284
# Epoch 84, CIFAR-10 Batch 1:  Loss:    1.0230 validation accuracy :0.6140
# Epoch 84, CIFAR-10 Batch 2:  Loss:    0.9147 validation accuracy :0.6238
# Epoch 84, CIFAR-10 Batch 3:  Loss:    0.9370 validation accuracy :0.6222
# Epoch 84, CIFAR-10 Batch 4:  Loss:    0.9549 validation accuracy :0.6040
# Epoch 84, CIFAR-10 Batch 5:  Loss:    0.9120 validation accuracy :0.6292
# Epoch 85, CIFAR-10 Batch 1:  Loss:    1.0248 validation accuracy :0.6136
# Epoch 85, CIFAR-10 Batch 2:  Loss:    0.9065 validation accuracy :0.6232
# Epoch 85, CIFAR-10 Batch 3:  Loss:    0.9342 validation accuracy :0.6188
# Epoch 85, CIFAR-10 Batch 4:  Loss:    0.9402 validation accuracy :0.6140
# Epoch 85, CIFAR-10 Batch 5:  Loss:    0.9065 validation accuracy :0.6286
# Epoch 86, CIFAR-10 Batch 1:  Loss:    1.0269 validation accuracy :0.6140
# Epoch 86, CIFAR-10 Batch 2:  Loss:    0.9101 validation accuracy :0.6240
# Epoch 86, CIFAR-10 Batch 3:  Loss:    0.9418 validation accuracy :0.6194
# Epoch 86, CIFAR-10 Batch 4:  Loss:    0.9488 validation accuracy :0.6118
# Epoch 86, CIFAR-10 Batch 5:  Loss:    0.9126 validation accuracy :0.6244
# Epoch 87, CIFAR-10 Batch 1:  Loss:    1.0229 validation accuracy :0.6154
# Epoch 87, CIFAR-10 Batch 2:  Loss:    0.9181 validation accuracy :0.6220
# Epoch 87, CIFAR-10 Batch 3:  Loss:    0.9353 validation accuracy :0.6230
# Epoch 87, CIFAR-10 Batch 4:  Loss:    0.9435 validation accuracy :0.6116
# Epoch 87, CIFAR-10 Batch 5:  Loss:    0.9041 validation accuracy :0.6224
# Epoch 88, CIFAR-10 Batch 1:  Loss:    1.0249 validation accuracy :0.6148
# Epoch 88, CIFAR-10 Batch 2:  Loss:    0.9066 validation accuracy :0.6198
# Epoch 88, CIFAR-10 Batch 3:  Loss:    0.9572 validation accuracy :0.6158
# Epoch 88, CIFAR-10 Batch 4:  Loss:    0.9477 validation accuracy :0.6108
# Epoch 88, CIFAR-10 Batch 5:  Loss:    0.8985 validation accuracy :0.6262
# Epoch 89, CIFAR-10 Batch 1:  Loss:    1.0136 validation accuracy :0.6186
# Epoch 89, CIFAR-10 Batch 2:  Loss:    0.9063 validation accuracy :0.6216
# Epoch 89, CIFAR-10 Batch 3:  Loss:    0.9564 validation accuracy :0.6160
# Epoch 89, CIFAR-10 Batch 4:  Loss:    0.9366 validation accuracy :0.6102
# Epoch 89, CIFAR-10 Batch 5:  Loss:    0.8976 validation accuracy :0.6294
# Epoch 90, CIFAR-10 Batch 1:  Loss:    1.0184 validation accuracy :0.6148
# Epoch 90, CIFAR-10 Batch 2:  Loss:    0.9132 validation accuracy :0.6234
# Epoch 90, CIFAR-10 Batch 3:  Loss:    0.9413 validation accuracy :0.6210
# Epoch 90, CIFAR-10 Batch 4:  Loss:    0.9346 validation accuracy :0.6144
# Epoch 90, CIFAR-10 Batch 5:  Loss:    0.8945 validation accuracy :0.6302
# Epoch 91, CIFAR-10 Batch 1:  Loss:    1.0179 validation accuracy :0.6158
# Epoch 91, CIFAR-10 Batch 2:  Loss:    0.9080 validation accuracy :0.6248
# Epoch 91, CIFAR-10 Batch 3:  Loss:    0.9635 validation accuracy :0.6114
# Epoch 91, CIFAR-10 Batch 4:  Loss:    0.9437 validation accuracy :0.6148
# Epoch 91, CIFAR-10 Batch 5:  Loss:    0.8905 validation accuracy :0.6296
# Epoch 92, CIFAR-10 Batch 1:  Loss:    1.0209 validation accuracy :0.6120
# Epoch 92, CIFAR-10 Batch 2:  Loss:    0.9158 validation accuracy :0.6146
# Epoch 92, CIFAR-10 Batch 3:  Loss:    0.9706 validation accuracy :0.6130
# Epoch 92, CIFAR-10 Batch 4:  Loss:    0.9651 validation accuracy :0.6074
# Epoch 92, CIFAR-10 Batch 5:  Loss:    0.8971 validation accuracy :0.6306
# Epoch 93, CIFAR-10 Batch 1:  Loss:    1.0117 validation accuracy :0.6204
# Epoch 93, CIFAR-10 Batch 2:  Loss:    0.9067 validation accuracy :0.6244
# Epoch 93, CIFAR-10 Batch 3:  Loss:    0.9596 validation accuracy :0.6188
# Epoch 93, CIFAR-10 Batch 4:  Loss:    0.9434 validation accuracy :0.6154
# Epoch 93, CIFAR-10 Batch 5:  Loss:    0.8898 validation accuracy :0.6280
# Epoch 94, CIFAR-10 Batch 1:  Loss:    1.0166 validation accuracy :0.6138
# Epoch 94, CIFAR-10 Batch 2:  Loss:    0.9094 validation accuracy :0.6192
# Epoch 94, CIFAR-10 Batch 3:  Loss:    0.9470 validation accuracy :0.6186
# Epoch 94, CIFAR-10 Batch 4:  Loss:    0.9425 validation accuracy :0.6182
# Epoch 94, CIFAR-10 Batch 5:  Loss:    0.8899 validation accuracy :0.6328
# Epoch 95, CIFAR-10 Batch 1:  Loss:    1.0072 validation accuracy :0.6174
# Epoch 95, CIFAR-10 Batch 2:  Loss:    0.9089 validation accuracy :0.6212
# Epoch 95, CIFAR-10 Batch 3:  Loss:    0.9453 validation accuracy :0.6176
# Epoch 95, CIFAR-10 Batch 4:  Loss:    0.9301 validation accuracy :0.6162
# Epoch 95, CIFAR-10 Batch 5:  Loss:    0.8959 validation accuracy :0.6312
# Epoch 96, CIFAR-10 Batch 1:  Loss:    1.0004 validation accuracy :0.6264
# Epoch 96, CIFAR-10 Batch 2:  Loss:    0.9053 validation accuracy :0.6242
# Epoch 96, CIFAR-10 Batch 3:  Loss:    0.9494 validation accuracy :0.6172
# Epoch 96, CIFAR-10 Batch 4:  Loss:    0.9327 validation accuracy :0.6126
# Epoch 96, CIFAR-10 Batch 5:  Loss:    0.8910 validation accuracy :0.6290
# Epoch 97, CIFAR-10 Batch 1:  Loss:    1.0041 validation accuracy :0.6216
# Epoch 97, CIFAR-10 Batch 2:  Loss:    0.9027 validation accuracy :0.6234
# Epoch 97, CIFAR-10 Batch 3:  Loss:    0.9546 validation accuracy :0.6148
# Epoch 97, CIFAR-10 Batch 4:  Loss:    0.9376 validation accuracy :0.6192
# Epoch 97, CIFAR-10 Batch 5:  Loss:    0.8880 validation accuracy :0.6336
# Epoch 98, CIFAR-10 Batch 1:  Loss:    1.0048 validation accuracy :0.6198
# Epoch 98, CIFAR-10 Batch 2:  Loss:    0.8975 validation accuracy :0.6246
# Epoch 98, CIFAR-10 Batch 3:  Loss:    0.9468 validation accuracy :0.6186
# Epoch 98, CIFAR-10 Batch 4:  Loss:    0.9310 validation accuracy :0.6136
# Epoch 98, CIFAR-10 Batch 5:  Loss:    0.8928 validation accuracy :0.6338
# Epoch 99, CIFAR-10 Batch 1:  Loss:    1.0059 validation accuracy :0.6140
# Epoch 99, CIFAR-10 Batch 2:  Loss:    0.9051 validation accuracy :0.6244
# Epoch 99, CIFAR-10 Batch 3:  Loss:    0.9265 validation accuracy :0.6212
# Epoch 99, CIFAR-10 Batch 4:  Loss:    0.9293 validation accuracy :0.6186
# Epoch 99, CIFAR-10 Batch 5:  Loss:    0.8866 validation accuracy :0.6334
# Epoch 100, CIFAR-10 Batch 1:  Loss:    1.0033 validation accuracy :0.6164
# Epoch 100, CIFAR-10 Batch 2:  Loss:    0.8976 validation accuracy :0.6270
# Epoch 100, CIFAR-10 Batch 3:  Loss:    0.9379 validation accuracy :0.6168
# Epoch 100, CIFAR-10 Batch 4:  Loss:    0.9315 validation accuracy :0.6140
# Epoch 100, CIFAR-10 Batch 5:  Loss:    0.8899 validation accuracy :0.6296

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6207261025905609

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
