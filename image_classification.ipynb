# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
#from urllib.request import urlretrieve
from os.path import isfile, isdir
import unittest
import problem_unittests as tests


cifar10_dataset_folder_path = 'cifar-10-batches-py'




tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    n=np.divide(x,256)
    return n


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
import pandas as pd
from sklearn import preprocessing
map_class=None
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    #print(map_class)
    lib=preprocessing.LabelBinarizer()
    global map_class
    if((map_class) is None):
        lib.fit(x) 
        map_class=lib.classes_        
    else:
        lib.classes_=map_class


    
    #print(lib.classes_)

    return lib.transform(x)  


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shp=[None]+list(image_shape)
    m=tf.placeholder(tf.float32,shape=tuple(shp),name='x')
    return m


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    shp=(None,n_classes)
 
    m=tf.placeholder(tf.float32,shape=(shp),name='y')
    return m


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    m=tf.placeholder(tf.float32,None,name='keep_prob')
    return m


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
   
    print(conv_strides)
    dimension=x_tensor.get_shape().as_list()
    shape=list( conv_ksize+(dimension[-1],)+(conv_num_outputs,))
    print(shape)
    filter_weights=tf.Variable( tf.truncated_normal(shape,0,0.1))
    filter_bias=tf.Variable(tf.zeros(conv_num_outputs))
    padding='SAME'

    strides=list((1,)+conv_strides+(1,))
    conv_layer=tf.nn.conv2d(x_tensor,filter_weights,strides=strides,padding='SAME')
    conv_layer=tf.nn.bias_add(conv_layer,filter_bias)
    conv_layer=tf.nn.relu(conv_layer)
    pool_ksize=[1]+list(pool_ksize)+[1]
    pool_strides=[1]+list(pool_strides)+[1]   
    conv_layer=tf.nn.max_pool(conv_layer,ksize=pool_ksize,strides=pool_strides,padding=padding)
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# (4, 4)
# [2, 2, 5, 10]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
from numpy import prod
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    dimension=x_tensor.get_shape().as_list()
    print(dimension)
    dim_new=tf.reshape(x_tensor,[-1,prod(dimension[1:])])
    print(dim_new)
    return dim_new


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# [None, 10, 30, 6]
# Tensor("Reshape:0", shape=(?, 1800), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimension=x_tensor.get_shape().as_list()
    shape=list((dimension[-1],)+(num_outputs,))
    
    print(shape)
    weight=tf.Variable(tf.truncated_normal(shape,0,0.1))
    bias=tf.Variable(tf.zeros(num_outputs))
    add_weight=tf.matmul(x_tensor,weight)
    add_bias=tf.add(add_weight,bias)
    full=tf.nn.relu(add_bias)
    return full


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# [128, 40]
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print(x_tensor)
    dimension=x_tensor.get_shape().as_list()
    shape=list((dimension[-1],)+(num_outputs,))
    weight=tf.Variable(tf.truncated_normal(shape,0,0.1))
    bias=tf.Variable(tf.zeros(num_outputs))
    add_weight=tf.matmul(x_tensor,weight)
    
    return tf.add(add_weight,bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tensor("Placeholder_9:0", shape=(?, 128), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    num_outputs=10
    model=conv2d_maxpool(x,conv_num_outputs=num_outputs,conv_ksize=(4,4),conv_strides=(1,1),pool_ksize=(8,8),pool_strides=(1,1))
    #model=conv2d_maxpool(x,18,(4,4),(1,1),pool_ksize=(8,8),pool_strides=(1,1))
    model=tf.nn.dropout(model,keep_prob)
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    model=flatten(model)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully_conn(model, num_outputs)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_value=output(model,num_outputs)
    
    # TODO: return output
    return output_value


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (1, 1)
# [4, 4, 3, 10]
# [None, 32, 32, 10]
# Tensor("Reshape:0", shape=(?, 10240), dtype=float32)
# [10240, 10]
# Tensor("Reshape:0", shape=(?, 10240), dtype=float32)
# (1, 1)
# [4, 4, 3, 10]
# [None, 32, 32, 10]
# Tensor("Reshape_4:0", shape=(?, 10240), dtype=float32)
# [10240, 10]
# Tensor("Reshape_4:0", shape=(?, 10240), dtype=float32)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch,y:label_batch,keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss=session.run(cost,feed_dict={x:feature_batch,y:label_batch,keep_prob:1.0})
    valid_acc=session.run(accuracy,feed_dict={x:valid_features,y:valid_labels,keep_prob:1.0})
    print("Loss:{:>10.4f} validation accuracy :{:.4f}".format(loss,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:    2.2061 validation accuracy :0.1952
# Epoch  2, CIFAR-10 Batch 1:  Loss:    2.1137 validation accuracy :0.2392
# Epoch  3, CIFAR-10 Batch 1:  Loss:    1.9984 validation accuracy :0.3192
# Epoch  4, CIFAR-10 Batch 1:  Loss:    1.8772 validation accuracy :0.3510
# Epoch  5, CIFAR-10 Batch 1:  Loss:    1.8004 validation accuracy :0.3758
# Epoch  6, CIFAR-10 Batch 1:  Loss:    1.7441 validation accuracy :0.3962
# Epoch  7, CIFAR-10 Batch 1:  Loss:    1.6862 validation accuracy :0.4130
# Epoch  8, CIFAR-10 Batch 1:  Loss:    1.6460 validation accuracy :0.4210
# Epoch  9, CIFAR-10 Batch 1:  Loss:    1.5975 validation accuracy :0.4312
# Epoch 10, CIFAR-10 Batch 1:  Loss:    1.5624 validation accuracy :0.4396
# Epoch 11, CIFAR-10 Batch 1:  Loss:    1.5138 validation accuracy :0.4478
# Epoch 12, CIFAR-10 Batch 1:  Loss:    1.4875 validation accuracy :0.4524
# Epoch 13, CIFAR-10 Batch 1:  Loss:    1.4685 validation accuracy :0.4530
# Epoch 14, CIFAR-10 Batch 1:  Loss:    1.4304 validation accuracy :0.4634
# Epoch 15, CIFAR-10 Batch 1:  Loss:    1.4008 validation accuracy :0.4676
# Epoch 16, CIFAR-10 Batch 1:  Loss:    1.3882 validation accuracy :0.4630
# Epoch 17, CIFAR-10 Batch 1:  Loss:    1.3683 validation accuracy :0.4678
# Epoch 18, CIFAR-10 Batch 1:  Loss:    1.3331 validation accuracy :0.4804
# Epoch 19, CIFAR-10 Batch 1:  Loss:    1.3240 validation accuracy :0.4798
# Epoch 20, CIFAR-10 Batch 1:  Loss:    1.2952 validation accuracy :0.4876
# Epoch 21, CIFAR-10 Batch 1:  Loss:    1.2788 validation accuracy :0.4956
# Epoch 22, CIFAR-10 Batch 1:  Loss:    1.2662 validation accuracy :0.4936
# Epoch 23, CIFAR-10 Batch 1:  Loss:    1.2484 validation accuracy :0.4984
# Epoch 24, CIFAR-10 Batch 1:  Loss:    1.2352 validation accuracy :0.5036
# Epoch 25, CIFAR-10 Batch 1:  Loss:    1.2260 validation accuracy :0.5064
# Epoch 26, CIFAR-10 Batch 1:  Loss:    1.2054 validation accuracy :0.5086
# Epoch 27, CIFAR-10 Batch 1:  Loss:    1.1912 validation accuracy :0.5142
# Epoch 28, CIFAR-10 Batch 1:  Loss:    1.1759 validation accuracy :0.5140
# Epoch 29, CIFAR-10 Batch 1:  Loss:    1.1675 validation accuracy :0.5120
# Epoch 30, CIFAR-10 Batch 1:  Loss:    1.1513 validation accuracy :0.5178
# Epoch 31, CIFAR-10 Batch 1:  Loss:    1.1404 validation accuracy :0.5146
# Epoch 32, CIFAR-10 Batch 1:  Loss:    1.1363 validation accuracy :0.5140
# Epoch 33, CIFAR-10 Batch 1:  Loss:    1.1176 validation accuracy :0.5242
# Epoch 34, CIFAR-10 Batch 1:  Loss:    1.1118 validation accuracy :0.5284
# Epoch 35, CIFAR-10 Batch 1:  Loss:    1.1014 validation accuracy :0.5240
# Epoch 36, CIFAR-10 Batch 1:  Loss:    1.1007 validation accuracy :0.5258
# Epoch 37, CIFAR-10 Batch 1:  Loss:    1.0928 validation accuracy :0.5236
# Epoch 38, CIFAR-10 Batch 1:  Loss:    1.0776 validation accuracy :0.5312
# Epoch 39, CIFAR-10 Batch 1:  Loss:    1.0693 validation accuracy :0.5318
# Epoch 40, CIFAR-10 Batch 1:  Loss:    1.0660 validation accuracy :0.5284
# Epoch 41, CIFAR-10 Batch 1:  Loss:    1.0607 validation accuracy :0.5270
# Epoch 42, CIFAR-10 Batch 1:  Loss:    1.0545 validation accuracy :0.5238
# Epoch 43, CIFAR-10 Batch 1:  Loss:    1.0557 validation accuracy :0.5274
# Epoch 44, CIFAR-10 Batch 1:  Loss:    1.0507 validation accuracy :0.5238
# Epoch 45, CIFAR-10 Batch 1:  Loss:    1.0408 validation accuracy :0.5304
# Epoch 46, CIFAR-10 Batch 1:  Loss:    1.0339 validation accuracy :0.5314
# Epoch 47, CIFAR-10 Batch 1:  Loss:    1.0250 validation accuracy :0.5398
# Epoch 48, CIFAR-10 Batch 1:  Loss:    1.0183 validation accuracy :0.5402
# Epoch 49, CIFAR-10 Batch 1:  Loss:    1.0117 validation accuracy :0.5354
# Epoch 50, CIFAR-10 Batch 1:  Loss:    1.0091 validation accuracy :0.5354
# Epoch 51, CIFAR-10 Batch 1:  Loss:    1.0063 validation accuracy :0.5398
# Epoch 52, CIFAR-10 Batch 1:  Loss:    1.0005 validation accuracy :0.5426
# Epoch 53, CIFAR-10 Batch 1:  Loss:    0.9990 validation accuracy :0.5356
# Epoch 54, CIFAR-10 Batch 1:  Loss:    0.9925 validation accuracy :0.5364
# Epoch 55, CIFAR-10 Batch 1:  Loss:    0.9716 validation accuracy :0.5400
# Epoch 56, CIFAR-10 Batch 1:  Loss:    0.9668 validation accuracy :0.5438
# Epoch 57, CIFAR-10 Batch 1:  Loss:    0.9656 validation accuracy :0.5394
# Epoch 58, CIFAR-10 Batch 1:  Loss:    0.9715 validation accuracy :0.5420
# Epoch 59, CIFAR-10 Batch 1:  Loss:    0.9632 validation accuracy :0.5424
# Epoch 60, CIFAR-10 Batch 1:  Loss:    0.9552 validation accuracy :0.5384
# Epoch 61, CIFAR-10 Batch 1:  Loss:    0.9514 validation accuracy :0.5492
# Epoch 62, CIFAR-10 Batch 1:  Loss:    0.9485 validation accuracy :0.5444
# Epoch 63, CIFAR-10 Batch 1:  Loss:    0.9463 validation accuracy :0.5486
# Epoch 64, CIFAR-10 Batch 1:  Loss:    0.9368 validation accuracy :0.5474
# Epoch 65, CIFAR-10 Batch 1:  Loss:    0.9414 validation accuracy :0.5456
# Epoch 66, CIFAR-10 Batch 1:  Loss:    0.9436 validation accuracy :0.5470
# Epoch 67, CIFAR-10 Batch 1:  Loss:    0.9346 validation accuracy :0.5446
# Epoch 68, CIFAR-10 Batch 1:  Loss:    0.9301 validation accuracy :0.5480
# Epoch 69, CIFAR-10 Batch 1:  Loss:    0.9290 validation accuracy :0.5496
# Epoch 70, CIFAR-10 Batch 1:  Loss:    0.9417 validation accuracy :0.5450
# Epoch 71, CIFAR-10 Batch 1:  Loss:    0.9209 validation accuracy :0.5522
# Epoch 72, CIFAR-10 Batch 1:  Loss:    0.9213 validation accuracy :0.5504
# Epoch 73, CIFAR-10 Batch 1:  Loss:    0.9125 validation accuracy :0.5454
# Epoch 74, CIFAR-10 Batch 1:  Loss:    0.9074 validation accuracy :0.5476
# Epoch 75, CIFAR-10 Batch 1:  Loss:    0.9101 validation accuracy :0.5456
# Epoch 76, CIFAR-10 Batch 1:  Loss:    0.9089 validation accuracy :0.5510
# Epoch 77, CIFAR-10 Batch 1:  Loss:    0.9031 validation accuracy :0.5506
# Epoch 78, CIFAR-10 Batch 1:  Loss:    0.8979 validation accuracy :0.5504
# Epoch 79, CIFAR-10 Batch 1:  Loss:    0.8982 validation accuracy :0.5496
# Epoch 80, CIFAR-10 Batch 1:  Loss:    0.8930 validation accuracy :0.5504
# Epoch 81, CIFAR-10 Batch 1:  Loss:    0.8888 validation accuracy :0.5552
# Epoch 82, CIFAR-10 Batch 1:  Loss:    0.8932 validation accuracy :0.5512
# Epoch 83, CIFAR-10 Batch 1:  Loss:    0.8875 validation accuracy :0.5532
# Epoch 84, CIFAR-10 Batch 1:  Loss:    0.8769 validation accuracy :0.5524
# Epoch 85, CIFAR-10 Batch 1:  Loss:    0.8787 validation accuracy :0.5550
# Epoch 86, CIFAR-10 Batch 1:  Loss:    0.8743 validation accuracy :0.5520
# Epoch 87, CIFAR-10 Batch 1:  Loss:    0.8762 validation accuracy :0.5512
# Epoch 88, CIFAR-10 Batch 1:  Loss:    0.8825 validation accuracy :0.5530
# Epoch 89, CIFAR-10 Batch 1:  Loss:    0.8774 validation accuracy :0.5548
# Epoch 90, CIFAR-10 Batch 1:  Loss:    0.8765 validation accuracy :0.5540
# Epoch 91, CIFAR-10 Batch 1:  Loss:    0.8706 validation accuracy :0.5552
# Epoch 92, CIFAR-10 Batch 1:  Loss:    0.8775 validation accuracy :0.5536
# Epoch 93, CIFAR-10 Batch 1:  Loss:    0.8667 validation accuracy :0.5556
# Epoch 94, CIFAR-10 Batch 1:  Loss:    0.8690 validation accuracy :0.5558
# Epoch 95, CIFAR-10 Batch 1:  Loss:    0.8632 validation accuracy :0.5534
# Epoch 96, CIFAR-10 Batch 1:  Loss:    0.8554 validation accuracy :0.5540
# Epoch 97, CIFAR-10 Batch 1:  Loss:    0.8587 validation accuracy :0.5556
# Epoch 98, CIFAR-10 Batch 1:  Loss:    0.8486 validation accuracy :0.5508
# Epoch 99, CIFAR-10 Batch 1:  Loss:    0.8529 validation accuracy :0.5504
# Epoch 100, CIFAR-10 Batch 1:  Loss:    0.8496 validation accuracy :0.5560

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:    2.2474 validation accuracy :0.1610
# Epoch  1, CIFAR-10 Batch 2:  Loss:    1.9723 validation accuracy :0.2972
# Epoch  1, CIFAR-10 Batch 3:  Loss:    1.7821 validation accuracy :0.3466
# Epoch  1, CIFAR-10 Batch 4:  Loss:    1.6936 validation accuracy :0.3794
# Epoch  1, CIFAR-10 Batch 5:  Loss:    1.6624 validation accuracy :0.4048
# Epoch  2, CIFAR-10 Batch 1:  Loss:    1.6758 validation accuracy :0.4302
# Epoch  2, CIFAR-10 Batch 2:  Loss:    1.5355 validation accuracy :0.4418
# Epoch  2, CIFAR-10 Batch 3:  Loss:    1.4747 validation accuracy :0.4554
# Epoch  2, CIFAR-10 Batch 4:  Loss:    1.4270 validation accuracy :0.4636
# Epoch  2, CIFAR-10 Batch 5:  Loss:    1.4731 validation accuracy :0.4734
# Epoch  3, CIFAR-10 Batch 1:  Loss:    1.5178 validation accuracy :0.4806
# Epoch  3, CIFAR-10 Batch 2:  Loss:    1.4341 validation accuracy :0.4700
# Epoch  3, CIFAR-10 Batch 3:  Loss:    1.3791 validation accuracy :0.4882
# Epoch  3, CIFAR-10 Batch 4:  Loss:    1.3392 validation accuracy :0.4894
# Epoch  3, CIFAR-10 Batch 5:  Loss:    1.3973 validation accuracy :0.4960
# Epoch  4, CIFAR-10 Batch 1:  Loss:    1.4518 validation accuracy :0.4974
# Epoch  4, CIFAR-10 Batch 2:  Loss:    1.3638 validation accuracy :0.4900
# Epoch  4, CIFAR-10 Batch 3:  Loss:    1.3299 validation accuracy :0.5114
# Epoch  4, CIFAR-10 Batch 4:  Loss:    1.2781 validation accuracy :0.5102
# Epoch  4, CIFAR-10 Batch 5:  Loss:    1.3492 validation accuracy :0.5160
# Epoch  5, CIFAR-10 Batch 1:  Loss:    1.3955 validation accuracy :0.5176
# Epoch  5, CIFAR-10 Batch 2:  Loss:    1.3048 validation accuracy :0.5134
# Epoch  5, CIFAR-10 Batch 3:  Loss:    1.2927 validation accuracy :0.5224
# Epoch  5, CIFAR-10 Batch 4:  Loss:    1.2532 validation accuracy :0.5160
# Epoch  5, CIFAR-10 Batch 5:  Loss:    1.3136 validation accuracy :0.5300
# Epoch  6, CIFAR-10 Batch 1:  Loss:    1.3553 validation accuracy :0.5310
# Epoch  6, CIFAR-10 Batch 2:  Loss:    1.2547 validation accuracy :0.5346
# Epoch  6, CIFAR-10 Batch 3:  Loss:    1.2553 validation accuracy :0.5362
# Epoch  6, CIFAR-10 Batch 4:  Loss:    1.2350 validation accuracy :0.5280
# Epoch  6, CIFAR-10 Batch 5:  Loss:    1.2870 validation accuracy :0.5454
# Epoch  7, CIFAR-10 Batch 1:  Loss:    1.3216 validation accuracy :0.5380
# Epoch  7, CIFAR-10 Batch 2:  Loss:    1.2290 validation accuracy :0.5420
# Epoch  7, CIFAR-10 Batch 3:  Loss:    1.2267 validation accuracy :0.5452
# Epoch  7, CIFAR-10 Batch 4:  Loss:    1.2083 validation accuracy :0.5408
# Epoch  7, CIFAR-10 Batch 5:  Loss:    1.2575 validation accuracy :0.5536
# Epoch  8, CIFAR-10 Batch 1:  Loss:    1.2970 validation accuracy :0.5490
# Epoch  8, CIFAR-10 Batch 2:  Loss:    1.2135 validation accuracy :0.5524
# Epoch  8, CIFAR-10 Batch 3:  Loss:    1.2019 validation accuracy :0.5492
# Epoch  8, CIFAR-10 Batch 4:  Loss:    1.1883 validation accuracy :0.5486
# Epoch  8, CIFAR-10 Batch 5:  Loss:    1.2364 validation accuracy :0.5614
# Epoch  9, CIFAR-10 Batch 1:  Loss:    1.2697 validation accuracy :0.5556
# Epoch  9, CIFAR-10 Batch 2:  Loss:    1.1903 validation accuracy :0.5528
# Epoch  9, CIFAR-10 Batch 3:  Loss:    1.1673 validation accuracy :0.5622
# Epoch  9, CIFAR-10 Batch 4:  Loss:    1.1734 validation accuracy :0.5578
# Epoch  9, CIFAR-10 Batch 5:  Loss:    1.2039 validation accuracy :0.5674
# Epoch 10, CIFAR-10 Batch 1:  Loss:    1.2607 validation accuracy :0.5606
# Epoch 10, CIFAR-10 Batch 2:  Loss:    1.1802 validation accuracy :0.5646
# Epoch 10, CIFAR-10 Batch 3:  Loss:    1.1571 validation accuracy :0.5718
# Epoch 10, CIFAR-10 Batch 4:  Loss:    1.1544 validation accuracy :0.5642
# Epoch 10, CIFAR-10 Batch 5:  Loss:    1.1731 validation accuracy :0.5764
# Epoch 11, CIFAR-10 Batch 1:  Loss:    1.2470 validation accuracy :0.5668
# Epoch 11, CIFAR-10 Batch 2:  Loss:    1.1561 validation accuracy :0.5676
# Epoch 11, CIFAR-10 Batch 3:  Loss:    1.1391 validation accuracy :0.5758
# Epoch 11, CIFAR-10 Batch 4:  Loss:    1.1404 validation accuracy :0.5676
# Epoch 11, CIFAR-10 Batch 5:  Loss:    1.1695 validation accuracy :0.5828
# Epoch 12, CIFAR-10 Batch 1:  Loss:    1.2295 validation accuracy :0.5718
# Epoch 12, CIFAR-10 Batch 2:  Loss:    1.1471 validation accuracy :0.5748
# Epoch 12, CIFAR-10 Batch 3:  Loss:    1.1130 validation accuracy :0.5828
# Epoch 12, CIFAR-10 Batch 4:  Loss:    1.1153 validation accuracy :0.5770
# Epoch 12, CIFAR-10 Batch 5:  Loss:    1.1435 validation accuracy :0.5888
# Epoch 13, CIFAR-10 Batch 1:  Loss:    1.2199 validation accuracy :0.5766
# Epoch 13, CIFAR-10 Batch 2:  Loss:    1.1318 validation accuracy :0.5808
# Epoch 13, CIFAR-10 Batch 3:  Loss:    1.1035 validation accuracy :0.5890
# Epoch 13, CIFAR-10 Batch 4:  Loss:    1.0994 validation accuracy :0.5842
# Epoch 13, CIFAR-10 Batch 5:  Loss:    1.1303 validation accuracy :0.5910
# Epoch 14, CIFAR-10 Batch 1:  Loss:    1.2130 validation accuracy :0.5784
# Epoch 14, CIFAR-10 Batch 2:  Loss:    1.1424 validation accuracy :0.5784
# Epoch 14, CIFAR-10 Batch 3:  Loss:    1.1041 validation accuracy :0.5868
# Epoch 14, CIFAR-10 Batch 4:  Loss:    1.0817 validation accuracy :0.5930
# Epoch 14, CIFAR-10 Batch 5:  Loss:    1.1150 validation accuracy :0.6000
# Epoch 15, CIFAR-10 Batch 1:  Loss:    1.2041 validation accuracy :0.5840
# Epoch 15, CIFAR-10 Batch 2:  Loss:    1.1269 validation accuracy :0.5840
# Epoch 15, CIFAR-10 Batch 3:  Loss:    1.0763 validation accuracy :0.5908
# Epoch 15, CIFAR-10 Batch 4:  Loss:    1.0744 validation accuracy :0.5924
# Epoch 15, CIFAR-10 Batch 5:  Loss:    1.0964 validation accuracy :0.5960
# Epoch 16, CIFAR-10 Batch 1:  Loss:    1.1990 validation accuracy :0.5838
# Epoch 16, CIFAR-10 Batch 2:  Loss:    1.1109 validation accuracy :0.5880
# Epoch 16, CIFAR-10 Batch 3:  Loss:    1.0635 validation accuracy :0.5966
# Epoch 16, CIFAR-10 Batch 4:  Loss:    1.0599 validation accuracy :0.5950
# Epoch 16, CIFAR-10 Batch 5:  Loss:    1.0930 validation accuracy :0.5942
# Epoch 17, CIFAR-10 Batch 1:  Loss:    1.1880 validation accuracy :0.5880
# Epoch 17, CIFAR-10 Batch 2:  Loss:    1.0951 validation accuracy :0.5924
# Epoch 17, CIFAR-10 Batch 3:  Loss:    1.0640 validation accuracy :0.5986
# Epoch 17, CIFAR-10 Batch 4:  Loss:    1.0610 validation accuracy :0.5948
# Epoch 17, CIFAR-10 Batch 5:  Loss:    1.0754 validation accuracy :0.6044
# Epoch 18, CIFAR-10 Batch 1:  Loss:    1.1848 validation accuracy :0.5898
# Epoch 18, CIFAR-10 Batch 2:  Loss:    1.1021 validation accuracy :0.5884
# Epoch 18, CIFAR-10 Batch 3:  Loss:    1.0449 validation accuracy :0.6006
# Epoch 18, CIFAR-10 Batch 4:  Loss:    1.0535 validation accuracy :0.5920
# Epoch 18, CIFAR-10 Batch 5:  Loss:    1.0662 validation accuracy :0.6040
# Epoch 19, CIFAR-10 Batch 1:  Loss:    1.1742 validation accuracy :0.5914
# Epoch 19, CIFAR-10 Batch 2:  Loss:    1.0996 validation accuracy :0.5904
# Epoch 19, CIFAR-10 Batch 3:  Loss:    1.0403 validation accuracy :0.6022
# Epoch 19, CIFAR-10 Batch 4:  Loss:    1.0425 validation accuracy :0.5940
# Epoch 19, CIFAR-10 Batch 5:  Loss:    1.0666 validation accuracy :0.5992
# Epoch 20, CIFAR-10 Batch 1:  Loss:    1.1740 validation accuracy :0.5964
# Epoch 20, CIFAR-10 Batch 2:  Loss:    1.0757 validation accuracy :0.6024
# Epoch 20, CIFAR-10 Batch 3:  Loss:    1.0439 validation accuracy :0.6008
# Epoch 20, CIFAR-10 Batch 4:  Loss:    1.0274 validation accuracy :0.5972
# Epoch 20, CIFAR-10 Batch 5:  Loss:    1.0506 validation accuracy :0.5990
# Epoch 21, CIFAR-10 Batch 1:  Loss:    1.1575 validation accuracy :0.5974
# Epoch 21, CIFAR-10 Batch 2:  Loss:    1.0578 validation accuracy :0.6024
# Epoch 21, CIFAR-10 Batch 3:  Loss:    1.0308 validation accuracy :0.6044
# Epoch 21, CIFAR-10 Batch 4:  Loss:    1.0231 validation accuracy :0.5976
# Epoch 21, CIFAR-10 Batch 5:  Loss:    1.0459 validation accuracy :0.6020
# Epoch 22, CIFAR-10 Batch 1:  Loss:    1.1615 validation accuracy :0.5920
# Epoch 22, CIFAR-10 Batch 2:  Loss:    1.0666 validation accuracy :0.6010
# Epoch 22, CIFAR-10 Batch 3:  Loss:    1.0286 validation accuracy :0.5966
# Epoch 22, CIFAR-10 Batch 4:  Loss:    1.0189 validation accuracy :0.6014
# Epoch 22, CIFAR-10 Batch 5:  Loss:    1.0256 validation accuracy :0.6002
# Epoch 23, CIFAR-10 Batch 1:  Loss:    1.1580 validation accuracy :0.5964
# Epoch 23, CIFAR-10 Batch 2:  Loss:    1.0498 validation accuracy :0.6070
# Epoch 23, CIFAR-10 Batch 3:  Loss:    1.0303 validation accuracy :0.6040
# Epoch 23, CIFAR-10 Batch 4:  Loss:    1.0160 validation accuracy :0.6006
# Epoch 23, CIFAR-10 Batch 5:  Loss:    1.0307 validation accuracy :0.5996
# Epoch 24, CIFAR-10 Batch 1:  Loss:    1.1505 validation accuracy :0.5990
# Epoch 24, CIFAR-10 Batch 2:  Loss:    1.0433 validation accuracy :0.6052
# Epoch 24, CIFAR-10 Batch 3:  Loss:    1.0330 validation accuracy :0.5966
# Epoch 24, CIFAR-10 Batch 4:  Loss:    1.0140 validation accuracy :0.6056
# Epoch 24, CIFAR-10 Batch 5:  Loss:    1.0064 validation accuracy :0.6004
# Epoch 25, CIFAR-10 Batch 1:  Loss:    1.1433 validation accuracy :0.6034
# Epoch 25, CIFAR-10 Batch 2:  Loss:    1.0417 validation accuracy :0.6038
# Epoch 25, CIFAR-10 Batch 3:  Loss:    1.0283 validation accuracy :0.6040
# Epoch 25, CIFAR-10 Batch 4:  Loss:    0.9927 validation accuracy :0.6082
# Epoch 25, CIFAR-10 Batch 5:  Loss:    1.0073 validation accuracy :0.6040
# Epoch 26, CIFAR-10 Batch 1:  Loss:    1.1370 validation accuracy :0.6030
# Epoch 26, CIFAR-10 Batch 2:  Loss:    1.0368 validation accuracy :0.6092
# Epoch 26, CIFAR-10 Batch 3:  Loss:    1.0192 validation accuracy :0.6012
# Epoch 26, CIFAR-10 Batch 4:  Loss:    0.9971 validation accuracy :0.6104
# Epoch 26, CIFAR-10 Batch 5:  Loss:    1.0079 validation accuracy :0.6086
# Epoch 27, CIFAR-10 Batch 1:  Loss:    1.1348 validation accuracy :0.6008
# Epoch 27, CIFAR-10 Batch 2:  Loss:    1.0224 validation accuracy :0.6100
# Epoch 27, CIFAR-10 Batch 3:  Loss:    1.0112 validation accuracy :0.6032
# Epoch 27, CIFAR-10 Batch 4:  Loss:    0.9992 validation accuracy :0.6072
# Epoch 27, CIFAR-10 Batch 5:  Loss:    1.0013 validation accuracy :0.6070
# Epoch 28, CIFAR-10 Batch 1:  Loss:    1.1268 validation accuracy :0.5980
# Epoch 28, CIFAR-10 Batch 2:  Loss:    1.0180 validation accuracy :0.6098
# Epoch 28, CIFAR-10 Batch 3:  Loss:    1.0323 validation accuracy :0.6074
# Epoch 28, CIFAR-10 Batch 4:  Loss:    0.9977 validation accuracy :0.6024
# Epoch 28, CIFAR-10 Batch 5:  Loss:    0.9904 validation accuracy :0.6104
# Epoch 29, CIFAR-10 Batch 1:  Loss:    1.1174 validation accuracy :0.6048
# Epoch 29, CIFAR-10 Batch 2:  Loss:    1.0186 validation accuracy :0.6092
# Epoch 29, CIFAR-10 Batch 3:  Loss:    1.0093 validation accuracy :0.6082
# Epoch 29, CIFAR-10 Batch 4:  Loss:    0.9836 validation accuracy :0.6062
# Epoch 29, CIFAR-10 Batch 5:  Loss:    0.9791 validation accuracy :0.6078
# Epoch 30, CIFAR-10 Batch 1:  Loss:    1.1161 validation accuracy :0.6044
# Epoch 30, CIFAR-10 Batch 2:  Loss:    1.0064 validation accuracy :0.6086
# Epoch 30, CIFAR-10 Batch 3:  Loss:    0.9956 validation accuracy :0.6116
# Epoch 30, CIFAR-10 Batch 4:  Loss:    0.9815 validation accuracy :0.6082
# Epoch 30, CIFAR-10 Batch 5:  Loss:    0.9792 validation accuracy :0.6104
# Epoch 31, CIFAR-10 Batch 1:  Loss:    1.1082 validation accuracy :0.6026
# Epoch 31, CIFAR-10 Batch 2:  Loss:    1.0160 validation accuracy :0.6102
# Epoch 31, CIFAR-10 Batch 3:  Loss:    1.0049 validation accuracy :0.6092
# Epoch 31, CIFAR-10 Batch 4:  Loss:    0.9696 validation accuracy :0.6096
# Epoch 31, CIFAR-10 Batch 5:  Loss:    0.9688 validation accuracy :0.6100
# Epoch 32, CIFAR-10 Batch 1:  Loss:    1.1140 validation accuracy :0.6064
# Epoch 32, CIFAR-10 Batch 2:  Loss:    0.9982 validation accuracy :0.6134
# Epoch 32, CIFAR-10 Batch 3:  Loss:    1.0152 validation accuracy :0.6078
# Epoch 32, CIFAR-10 Batch 4:  Loss:    0.9671 validation accuracy :0.6094
# Epoch 32, CIFAR-10 Batch 5:  Loss:    0.9688 validation accuracy :0.6120
# Epoch 33, CIFAR-10 Batch 1:  Loss:    1.1037 validation accuracy :0.6052
# Epoch 33, CIFAR-10 Batch 2:  Loss:    1.0042 validation accuracy :0.6130
# Epoch 33, CIFAR-10 Batch 3:  Loss:    1.0014 validation accuracy :0.6068
# Epoch 33, CIFAR-10 Batch 4:  Loss:    0.9598 validation accuracy :0.6128
# Epoch 33, CIFAR-10 Batch 5:  Loss:    0.9669 validation accuracy :0.6160
# Epoch 34, CIFAR-10 Batch 1:  Loss:    1.0973 validation accuracy :0.6074
# Epoch 34, CIFAR-10 Batch 2:  Loss:    0.9893 validation accuracy :0.6134
# Epoch 34, CIFAR-10 Batch 3:  Loss:    1.0038 validation accuracy :0.6088
# Epoch 34, CIFAR-10 Batch 4:  Loss:    0.9641 validation accuracy :0.6110
# Epoch 34, CIFAR-10 Batch 5:  Loss:    0.9639 validation accuracy :0.6086
# Epoch 35, CIFAR-10 Batch 1:  Loss:    1.1023 validation accuracy :0.6114
# Epoch 35, CIFAR-10 Batch 2:  Loss:    0.9983 validation accuracy :0.6130
# Epoch 35, CIFAR-10 Batch 3:  Loss:    0.9992 validation accuracy :0.6102
# Epoch 35, CIFAR-10 Batch 4:  Loss:    0.9633 validation accuracy :0.6122
# Epoch 35, CIFAR-10 Batch 5:  Loss:    0.9612 validation accuracy :0.6070
# Epoch 36, CIFAR-10 Batch 1:  Loss:    1.0913 validation accuracy :0.6092
# Epoch 36, CIFAR-10 Batch 2:  Loss:    0.9926 validation accuracy :0.6144
# Epoch 36, CIFAR-10 Batch 3:  Loss:    0.9907 validation accuracy :0.6108
# Epoch 36, CIFAR-10 Batch 4:  Loss:    0.9487 validation accuracy :0.6142
# Epoch 36, CIFAR-10 Batch 5:  Loss:    0.9530 validation accuracy :0.6116
# Epoch 37, CIFAR-10 Batch 1:  Loss:    1.0788 validation accuracy :0.6136
# Epoch 37, CIFAR-10 Batch 2:  Loss:    0.9924 validation accuracy :0.6124
# Epoch 37, CIFAR-10 Batch 3:  Loss:    0.9976 validation accuracy :0.6124
# Epoch 37, CIFAR-10 Batch 4:  Loss:    0.9457 validation accuracy :0.6134
# Epoch 37, CIFAR-10 Batch 5:  Loss:    0.9471 validation accuracy :0.6214
# Epoch 38, CIFAR-10 Batch 1:  Loss:    1.0870 validation accuracy :0.6058
# Epoch 38, CIFAR-10 Batch 2:  Loss:    0.9914 validation accuracy :0.6148
# Epoch 38, CIFAR-10 Batch 3:  Loss:    0.9925 validation accuracy :0.6126
# Epoch 38, CIFAR-10 Batch 4:  Loss:    0.9409 validation accuracy :0.6180
# Epoch 38, CIFAR-10 Batch 5:  Loss:    0.9477 validation accuracy :0.6138
# Epoch 39, CIFAR-10 Batch 1:  Loss:    1.0897 validation accuracy :0.6100
# Epoch 39, CIFAR-10 Batch 2:  Loss:    0.9884 validation accuracy :0.6126
# Epoch 39, CIFAR-10 Batch 3:  Loss:    0.9875 validation accuracy :0.6122
# Epoch 39, CIFAR-10 Batch 4:  Loss:    0.9392 validation accuracy :0.6146
# Epoch 39, CIFAR-10 Batch 5:  Loss:    0.9480 validation accuracy :0.6214
# Epoch 40, CIFAR-10 Batch 1:  Loss:    1.0735 validation accuracy :0.6102
# Epoch 40, CIFAR-10 Batch 2:  Loss:    0.9706 validation accuracy :0.6178
# Epoch 40, CIFAR-10 Batch 3:  Loss:    0.9832 validation accuracy :0.6122
# Epoch 40, CIFAR-10 Batch 4:  Loss:    0.9423 validation accuracy :0.6170
# Epoch 40, CIFAR-10 Batch 5:  Loss:    0.9460 validation accuracy :0.6138
# Epoch 41, CIFAR-10 Batch 1:  Loss:    1.0761 validation accuracy :0.6112
# Epoch 41, CIFAR-10 Batch 2:  Loss:    0.9723 validation accuracy :0.6180
# Epoch 41, CIFAR-10 Batch 3:  Loss:    0.9848 validation accuracy :0.6146
# Epoch 41, CIFAR-10 Batch 4:  Loss:    0.9408 validation accuracy :0.6148
# Epoch 41, CIFAR-10 Batch 5:  Loss:    0.9430 validation accuracy :0.6230
# Epoch 42, CIFAR-10 Batch 1:  Loss:    1.0729 validation accuracy :0.6130
# Epoch 42, CIFAR-10 Batch 2:  Loss:    0.9703 validation accuracy :0.6196
# Epoch 42, CIFAR-10 Batch 3:  Loss:    0.9876 validation accuracy :0.6120
# Epoch 42, CIFAR-10 Batch 4:  Loss:    0.9255 validation accuracy :0.6194
# Epoch 42, CIFAR-10 Batch 5:  Loss:    0.9397 validation accuracy :0.6188
# Epoch 43, CIFAR-10 Batch 1:  Loss:    1.0773 validation accuracy :0.6152
# Epoch 43, CIFAR-10 Batch 2:  Loss:    0.9619 validation accuracy :0.6204
# Epoch 43, CIFAR-10 Batch 3:  Loss:    0.9801 validation accuracy :0.6182
# Epoch 43, CIFAR-10 Batch 4:  Loss:    0.9227 validation accuracy :0.6224
# Epoch 43, CIFAR-10 Batch 5:  Loss:    0.9391 validation accuracy :0.6136
# Epoch 44, CIFAR-10 Batch 1:  Loss:    1.0738 validation accuracy :0.6096
# Epoch 44, CIFAR-10 Batch 2:  Loss:    0.9859 validation accuracy :0.6170
# Epoch 44, CIFAR-10 Batch 3:  Loss:    0.9771 validation accuracy :0.6136
# Epoch 44, CIFAR-10 Batch 4:  Loss:    0.9282 validation accuracy :0.6178
# Epoch 44, CIFAR-10 Batch 5:  Loss:    0.9325 validation accuracy :0.6168
# Epoch 45, CIFAR-10 Batch 1:  Loss:    1.0671 validation accuracy :0.6142
# Epoch 45, CIFAR-10 Batch 2:  Loss:    0.9731 validation accuracy :0.6190
# Epoch 45, CIFAR-10 Batch 3:  Loss:    0.9865 validation accuracy :0.6132
# Epoch 45, CIFAR-10 Batch 4:  Loss:    0.9117 validation accuracy :0.6196
# Epoch 45, CIFAR-10 Batch 5:  Loss:    0.9280 validation accuracy :0.6192
# Epoch 46, CIFAR-10 Batch 1:  Loss:    1.0619 validation accuracy :0.6150
# Epoch 46, CIFAR-10 Batch 2:  Loss:    0.9553 validation accuracy :0.6232
# Epoch 46, CIFAR-10 Batch 3:  Loss:    0.9833 validation accuracy :0.6152
# Epoch 46, CIFAR-10 Batch 4:  Loss:    0.9109 validation accuracy :0.6190
# Epoch 46, CIFAR-10 Batch 5:  Loss:    0.9291 validation accuracy :0.6254
# Epoch 47, CIFAR-10 Batch 1:  Loss:    1.0647 validation accuracy :0.6086
# Epoch 47, CIFAR-10 Batch 2:  Loss:    0.9549 validation accuracy :0.6218
# Epoch 47, CIFAR-10 Batch 3:  Loss:    0.9840 validation accuracy :0.6186
# Epoch 47, CIFAR-10 Batch 4:  Loss:    0.9125 validation accuracy :0.6190
# Epoch 47, CIFAR-10 Batch 5:  Loss:    0.9218 validation accuracy :0.6234
# Epoch 48, CIFAR-10 Batch 1:  Loss:    1.0625 validation accuracy :0.6144
# Epoch 48, CIFAR-10 Batch 2:  Loss:    0.9623 validation accuracy :0.6200
# Epoch 48, CIFAR-10 Batch 3:  Loss:    0.9671 validation accuracy :0.6212
# Epoch 48, CIFAR-10 Batch 4:  Loss:    0.9120 validation accuracy :0.6200
# Epoch 48, CIFAR-10 Batch 5:  Loss:    0.9229 validation accuracy :0.6196
# Epoch 49, CIFAR-10 Batch 1:  Loss:    1.0561 validation accuracy :0.6130
# Epoch 49, CIFAR-10 Batch 2:  Loss:    0.9521 validation accuracy :0.6208
# Epoch 49, CIFAR-10 Batch 3:  Loss:    0.9755 validation accuracy :0.6190
# Epoch 49, CIFAR-10 Batch 4:  Loss:    0.9019 validation accuracy :0.6216
# Epoch 49, CIFAR-10 Batch 5:  Loss:    0.9157 validation accuracy :0.6230
# Epoch 50, CIFAR-10 Batch 1:  Loss:    1.0579 validation accuracy :0.6120
# Epoch 50, CIFAR-10 Batch 2:  Loss:    0.9523 validation accuracy :0.6216
# Epoch 50, CIFAR-10 Batch 3:  Loss:    0.9743 validation accuracy :0.6196
# Epoch 50, CIFAR-10 Batch 4:  Loss:    0.9023 validation accuracy :0.6214
# Epoch 50, CIFAR-10 Batch 5:  Loss:    0.9149 validation accuracy :0.6236
# Epoch 51, CIFAR-10 Batch 1:  Loss:    1.0508 validation accuracy :0.6178
# Epoch 51, CIFAR-10 Batch 2:  Loss:    0.9459 validation accuracy :0.6236
# Epoch 51, CIFAR-10 Batch 3:  Loss:    0.9905 validation accuracy :0.6156
# Epoch 51, CIFAR-10 Batch 4:  Loss:    0.9045 validation accuracy :0.6232
# Epoch 51, CIFAR-10 Batch 5:  Loss:    0.9142 validation accuracy :0.6262
# Epoch 52, CIFAR-10 Batch 1:  Loss:    1.0512 validation accuracy :0.6180
# Epoch 52, CIFAR-10 Batch 2:  Loss:    0.9541 validation accuracy :0.6190
# Epoch 52, CIFAR-10 Batch 3:  Loss:    0.9738 validation accuracy :0.6176
# Epoch 52, CIFAR-10 Batch 4:  Loss:    0.9054 validation accuracy :0.6198
# Epoch 52, CIFAR-10 Batch 5:  Loss:    0.9105 validation accuracy :0.6228
# Epoch 53, CIFAR-10 Batch 1:  Loss:    1.0547 validation accuracy :0.6202
# Epoch 53, CIFAR-10 Batch 2:  Loss:    0.9423 validation accuracy :0.6214
# Epoch 53, CIFAR-10 Batch 3:  Loss:    0.9686 validation accuracy :0.6216
# Epoch 53, CIFAR-10 Batch 4:  Loss:    0.8992 validation accuracy :0.6216
# Epoch 53, CIFAR-10 Batch 5:  Loss:    0.9099 validation accuracy :0.6274
# Epoch 54, CIFAR-10 Batch 1:  Loss:    1.0494 validation accuracy :0.6174
# Epoch 54, CIFAR-10 Batch 2:  Loss:    0.9297 validation accuracy :0.6256
# Epoch 54, CIFAR-10 Batch 3:  Loss:    0.9663 validation accuracy :0.6214
# Epoch 54, CIFAR-10 Batch 4:  Loss:    0.8990 validation accuracy :0.6208
# Epoch 54, CIFAR-10 Batch 5:  Loss:    0.9078 validation accuracy :0.6268
# Epoch 55, CIFAR-10 Batch 1:  Loss:    1.0488 validation accuracy :0.6190
# Epoch 55, CIFAR-10 Batch 2:  Loss:    0.9353 validation accuracy :0.6252
# Epoch 55, CIFAR-10 Batch 3:  Loss:    0.9702 validation accuracy :0.6198
# Epoch 55, CIFAR-10 Batch 4:  Loss:    0.9020 validation accuracy :0.6190
# Epoch 55, CIFAR-10 Batch 5:  Loss:    0.9146 validation accuracy :0.6208
# Epoch 56, CIFAR-10 Batch 1:  Loss:    1.0476 validation accuracy :0.6180
# Epoch 56, CIFAR-10 Batch 2:  Loss:    0.9539 validation accuracy :0.6176
# Epoch 56, CIFAR-10 Batch 3:  Loss:    0.9596 validation accuracy :0.6244
# Epoch 56, CIFAR-10 Batch 4:  Loss:    0.8961 validation accuracy :0.6248
# Epoch 56, CIFAR-10 Batch 5:  Loss:    0.9076 validation accuracy :0.6244
# Epoch 57, CIFAR-10 Batch 1:  Loss:    1.0477 validation accuracy :0.6214
# Epoch 57, CIFAR-10 Batch 2:  Loss:    0.9344 validation accuracy :0.6248
# Epoch 57, CIFAR-10 Batch 3:  Loss:    0.9677 validation accuracy :0.6184
# Epoch 57, CIFAR-10 Batch 4:  Loss:    0.8878 validation accuracy :0.6272
# Epoch 57, CIFAR-10 Batch 5:  Loss:    0.9075 validation accuracy :0.6278
# Epoch 58, CIFAR-10 Batch 1:  Loss:    1.0484 validation accuracy :0.6154
# Epoch 58, CIFAR-10 Batch 2:  Loss:    0.9428 validation accuracy :0.6194
# Epoch 58, CIFAR-10 Batch 3:  Loss:    0.9617 validation accuracy :0.6244
# Epoch 58, CIFAR-10 Batch 4:  Loss:    0.8958 validation accuracy :0.6216
# Epoch 58, CIFAR-10 Batch 5:  Loss:    0.9076 validation accuracy :0.6280
# Epoch 59, CIFAR-10 Batch 1:  Loss:    1.0550 validation accuracy :0.6178
# Epoch 59, CIFAR-10 Batch 2:  Loss:    0.9479 validation accuracy :0.6222
# Epoch 59, CIFAR-10 Batch 3:  Loss:    0.9670 validation accuracy :0.6212
# Epoch 59, CIFAR-10 Batch 4:  Loss:    0.8845 validation accuracy :0.6252
# Epoch 59, CIFAR-10 Batch 5:  Loss:    0.9039 validation accuracy :0.6260
# Epoch 60, CIFAR-10 Batch 1:  Loss:    1.0394 validation accuracy :0.6206
# Epoch 60, CIFAR-10 Batch 2:  Loss:    0.9442 validation accuracy :0.6172
# Epoch 60, CIFAR-10 Batch 3:  Loss:    0.9542 validation accuracy :0.6218
# Epoch 60, CIFAR-10 Batch 4:  Loss:    0.8781 validation accuracy :0.6258
# Epoch 60, CIFAR-10 Batch 5:  Loss:    0.9027 validation accuracy :0.6266
# Epoch 61, CIFAR-10 Batch 1:  Loss:    1.0444 validation accuracy :0.6158
# Epoch 61, CIFAR-10 Batch 2:  Loss:    0.9189 validation accuracy :0.6250
# Epoch 61, CIFAR-10 Batch 3:  Loss:    0.9637 validation accuracy :0.6188
# Epoch 61, CIFAR-10 Batch 4:  Loss:    0.8895 validation accuracy :0.6226
# Epoch 61, CIFAR-10 Batch 5:  Loss:    0.9003 validation accuracy :0.6256
# Epoch 62, CIFAR-10 Batch 1:  Loss:    1.0370 validation accuracy :0.6202
# Epoch 62, CIFAR-10 Batch 2:  Loss:    0.9338 validation accuracy :0.6278
# Epoch 62, CIFAR-10 Batch 3:  Loss:    0.9594 validation accuracy :0.6212
# Epoch 62, CIFAR-10 Batch 4:  Loss:    0.8816 validation accuracy :0.6232
# Epoch 62, CIFAR-10 Batch 5:  Loss:    0.8975 validation accuracy :0.6222
# Epoch 63, CIFAR-10 Batch 1:  Loss:    1.0433 validation accuracy :0.6188
# Epoch 63, CIFAR-10 Batch 2:  Loss:    0.9218 validation accuracy :0.6292
# Epoch 63, CIFAR-10 Batch 3:  Loss:    0.9627 validation accuracy :0.6186
# Epoch 63, CIFAR-10 Batch 4:  Loss:    0.8861 validation accuracy :0.6240
# Epoch 63, CIFAR-10 Batch 5:  Loss:    0.9026 validation accuracy :0.6234
# Epoch 64, CIFAR-10 Batch 1:  Loss:    1.0383 validation accuracy :0.6230
# Epoch 64, CIFAR-10 Batch 2:  Loss:    0.9311 validation accuracy :0.6296
# Epoch 64, CIFAR-10 Batch 3:  Loss:    0.9495 validation accuracy :0.6222
# Epoch 64, CIFAR-10 Batch 4:  Loss:    0.8831 validation accuracy :0.6204
# Epoch 64, CIFAR-10 Batch 5:  Loss:    0.8911 validation accuracy :0.6290
# Epoch 65, CIFAR-10 Batch 1:  Loss:    1.0383 validation accuracy :0.6186
# Epoch 65, CIFAR-10 Batch 2:  Loss:    0.9304 validation accuracy :0.6246
# Epoch 65, CIFAR-10 Batch 3:  Loss:    0.9533 validation accuracy :0.6242
# Epoch 65, CIFAR-10 Batch 4:  Loss:    0.8847 validation accuracy :0.6216
# Epoch 65, CIFAR-10 Batch 5:  Loss:    0.8910 validation accuracy :0.6304
# Epoch 66, CIFAR-10 Batch 1:  Loss:    1.0310 validation accuracy :0.6244
# Epoch 66, CIFAR-10 Batch 2:  Loss:    0.9253 validation accuracy :0.6284
# Epoch 66, CIFAR-10 Batch 3:  Loss:    0.9549 validation accuracy :0.6240
# Epoch 66, CIFAR-10 Batch 4:  Loss:    0.8845 validation accuracy :0.6224
# Epoch 66, CIFAR-10 Batch 5:  Loss:    0.8905 validation accuracy :0.6312
# Epoch 67, CIFAR-10 Batch 1:  Loss:    1.0331 validation accuracy :0.6240
# Epoch 67, CIFAR-10 Batch 2:  Loss:    0.9210 validation accuracy :0.6308
# Epoch 67, CIFAR-10 Batch 3:  Loss:    0.9518 validation accuracy :0.6192
# Epoch 67, CIFAR-10 Batch 4:  Loss:    0.8825 validation accuracy :0.6262
# Epoch 67, CIFAR-10 Batch 5:  Loss:    0.8885 validation accuracy :0.6264
# Epoch 68, CIFAR-10 Batch 1:  Loss:    1.0346 validation accuracy :0.6190
# Epoch 68, CIFAR-10 Batch 2:  Loss:    0.9227 validation accuracy :0.6286
# Epoch 68, CIFAR-10 Batch 3:  Loss:    0.9548 validation accuracy :0.6244
# Epoch 68, CIFAR-10 Batch 4:  Loss:    0.8738 validation accuracy :0.6228
# Epoch 68, CIFAR-10 Batch 5:  Loss:    0.8882 validation accuracy :0.6278
# Epoch 69, CIFAR-10 Batch 1:  Loss:    1.0338 validation accuracy :0.6242
# Epoch 69, CIFAR-10 Batch 2:  Loss:    0.9186 validation accuracy :0.6296
# Epoch 69, CIFAR-10 Batch 3:  Loss:    0.9531 validation accuracy :0.6204
# Epoch 69, CIFAR-10 Batch 4:  Loss:    0.8774 validation accuracy :0.6210
# Epoch 69, CIFAR-10 Batch 5:  Loss:    0.8860 validation accuracy :0.6268
# Epoch 70, CIFAR-10 Batch 1:  Loss:    1.0296 validation accuracy :0.6218
# Epoch 70, CIFAR-10 Batch 2:  Loss:    0.9209 validation accuracy :0.6282
# Epoch 70, CIFAR-10 Batch 3:  Loss:    0.9505 validation accuracy :0.6218
# Epoch 70, CIFAR-10 Batch 4:  Loss:    0.8725 validation accuracy :0.6222
# Epoch 70, CIFAR-10 Batch 5:  Loss:    0.8889 validation accuracy :0.6236
# Epoch 71, CIFAR-10 Batch 1:  Loss:    1.0318 validation accuracy :0.6208
# Epoch 71, CIFAR-10 Batch 2:  Loss:    0.9269 validation accuracy :0.6244
# Epoch 71, CIFAR-10 Batch 3:  Loss:    0.9538 validation accuracy :0.6210
# Epoch 71, CIFAR-10 Batch 4:  Loss:    0.8773 validation accuracy :0.6214
# Epoch 71, CIFAR-10 Batch 5:  Loss:    0.8971 validation accuracy :0.6202
# Epoch 72, CIFAR-10 Batch 1:  Loss:    1.0289 validation accuracy :0.6220
# Epoch 72, CIFAR-10 Batch 2:  Loss:    0.9131 validation accuracy :0.6288
# Epoch 72, CIFAR-10 Batch 3:  Loss:    0.9412 validation accuracy :0.6266
# Epoch 72, CIFAR-10 Batch 4:  Loss:    0.8874 validation accuracy :0.6172
# Epoch 72, CIFAR-10 Batch 5:  Loss:    0.8923 validation accuracy :0.6234
# Epoch 73, CIFAR-10 Batch 1:  Loss:    1.0320 validation accuracy :0.6222
# Epoch 73, CIFAR-10 Batch 2:  Loss:    0.9052 validation accuracy :0.6352
# Epoch 73, CIFAR-10 Batch 3:  Loss:    0.9472 validation accuracy :0.6272
# Epoch 73, CIFAR-10 Batch 4:  Loss:    0.8720 validation accuracy :0.6260
# Epoch 73, CIFAR-10 Batch 5:  Loss:    0.8873 validation accuracy :0.6264
# Epoch 74, CIFAR-10 Batch 1:  Loss:    1.0244 validation accuracy :0.6212
# Epoch 74, CIFAR-10 Batch 2:  Loss:    0.9098 validation accuracy :0.6316
# Epoch 74, CIFAR-10 Batch 3:  Loss:    0.9503 validation accuracy :0.6248
# Epoch 74, CIFAR-10 Batch 4:  Loss:    0.8740 validation accuracy :0.6244
# Epoch 74, CIFAR-10 Batch 5:  Loss:    0.8872 validation accuracy :0.6250
# Epoch 75, CIFAR-10 Batch 1:  Loss:    1.0317 validation accuracy :0.6168
# Epoch 75, CIFAR-10 Batch 2:  Loss:    0.9168 validation accuracy :0.6308
# Epoch 75, CIFAR-10 Batch 3:  Loss:    0.9594 validation accuracy :0.6192
# Epoch 75, CIFAR-10 Batch 4:  Loss:    0.8781 validation accuracy :0.6216
# Epoch 75, CIFAR-10 Batch 5:  Loss:    0.8931 validation accuracy :0.6186
# Epoch 76, CIFAR-10 Batch 1:  Loss:    1.0231 validation accuracy :0.6186
# Epoch 76, CIFAR-10 Batch 2:  Loss:    0.9215 validation accuracy :0.6290
# Epoch 76, CIFAR-10 Batch 3:  Loss:    0.9575 validation accuracy :0.6184
# Epoch 76, CIFAR-10 Batch 4:  Loss:    0.8768 validation accuracy :0.6238
# Epoch 76, CIFAR-10 Batch 5:  Loss:    0.8810 validation accuracy :0.6240
# Epoch 77, CIFAR-10 Batch 1:  Loss:    1.0225 validation accuracy :0.6182
# Epoch 77, CIFAR-10 Batch 2:  Loss:    0.9030 validation accuracy :0.6312
# Epoch 77, CIFAR-10 Batch 3:  Loss:    0.9577 validation accuracy :0.6198
# Epoch 77, CIFAR-10 Batch 4:  Loss:    0.8835 validation accuracy :0.6172
# Epoch 77, CIFAR-10 Batch 5:  Loss:    0.8943 validation accuracy :0.6204
# Epoch 78, CIFAR-10 Batch 1:  Loss:    1.0293 validation accuracy :0.6184
# Epoch 78, CIFAR-10 Batch 2:  Loss:    0.9012 validation accuracy :0.6340
# Epoch 78, CIFAR-10 Batch 3:  Loss:    0.9484 validation accuracy :0.6270
# Epoch 78, CIFAR-10 Batch 4:  Loss:    0.8742 validation accuracy :0.6234
# Epoch 78, CIFAR-10 Batch 5:  Loss:    0.8856 validation accuracy :0.6214
# Epoch 79, CIFAR-10 Batch 1:  Loss:    1.0221 validation accuracy :0.6150
# Epoch 79, CIFAR-10 Batch 2:  Loss:    0.8973 validation accuracy :0.6298
# Epoch 79, CIFAR-10 Batch 3:  Loss:    0.9530 validation accuracy :0.6246
# Epoch 79, CIFAR-10 Batch 4:  Loss:    0.8691 validation accuracy :0.6258
# Epoch 79, CIFAR-10 Batch 5:  Loss:    0.8812 validation accuracy :0.6260
# Epoch 80, CIFAR-10 Batch 1:  Loss:    1.0175 validation accuracy :0.6238
# Epoch 80, CIFAR-10 Batch 2:  Loss:    0.8987 validation accuracy :0.6302
# Epoch 80, CIFAR-10 Batch 3:  Loss:    0.9499 validation accuracy :0.6258
# Epoch 80, CIFAR-10 Batch 4:  Loss:    0.8652 validation accuracy :0.6270
# Epoch 80, CIFAR-10 Batch 5:  Loss:    0.8860 validation accuracy :0.6274
# Epoch 81, CIFAR-10 Batch 1:  Loss:    1.0181 validation accuracy :0.6192
# Epoch 81, CIFAR-10 Batch 2:  Loss:    0.9075 validation accuracy :0.6270
# Epoch 81, CIFAR-10 Batch 3:  Loss:    0.9466 validation accuracy :0.6264
# Epoch 81, CIFAR-10 Batch 4:  Loss:    0.8735 validation accuracy :0.6228
# Epoch 81, CIFAR-10 Batch 5:  Loss:    0.8807 validation accuracy :0.6252
# Epoch 82, CIFAR-10 Batch 1:  Loss:    1.0128 validation accuracy :0.6196
# Epoch 82, CIFAR-10 Batch 2:  Loss:    0.9042 validation accuracy :0.6274
# Epoch 82, CIFAR-10 Batch 3:  Loss:    0.9606 validation accuracy :0.6208
# Epoch 82, CIFAR-10 Batch 4:  Loss:    0.8633 validation accuracy :0.6248
# Epoch 82, CIFAR-10 Batch 5:  Loss:    0.8873 validation accuracy :0.6208
# Epoch 83, CIFAR-10 Batch 1:  Loss:    1.0258 validation accuracy :0.6170
# Epoch 83, CIFAR-10 Batch 2:  Loss:    0.9000 validation accuracy :0.6284
# Epoch 83, CIFAR-10 Batch 3:  Loss:    0.9667 validation accuracy :0.6204
# Epoch 83, CIFAR-10 Batch 4:  Loss:    0.8688 validation accuracy :0.6232
# Epoch 83, CIFAR-10 Batch 5:  Loss:    0.8822 validation accuracy :0.6228
# Epoch 84, CIFAR-10 Batch 1:  Loss:    1.0239 validation accuracy :0.6178
# Epoch 84, CIFAR-10 Batch 2:  Loss:    0.8964 validation accuracy :0.6288
# Epoch 84, CIFAR-10 Batch 3:  Loss:    0.9470 validation accuracy :0.6252
# Epoch 84, CIFAR-10 Batch 4:  Loss:    0.8732 validation accuracy :0.6226
# Epoch 84, CIFAR-10 Batch 5:  Loss:    0.8769 validation accuracy :0.6244
# Epoch 85, CIFAR-10 Batch 1:  Loss:    1.0201 validation accuracy :0.6180
# Epoch 85, CIFAR-10 Batch 2:  Loss:    0.9077 validation accuracy :0.6310
# Epoch 85, CIFAR-10 Batch 3:  Loss:    0.9413 validation accuracy :0.6266
# Epoch 85, CIFAR-10 Batch 4:  Loss:    0.8638 validation accuracy :0.6260
# Epoch 85, CIFAR-10 Batch 5:  Loss:    0.8818 validation accuracy :0.6242
# Epoch 86, CIFAR-10 Batch 1:  Loss:    1.0131 validation accuracy :0.6230
# Epoch 86, CIFAR-10 Batch 2:  Loss:    0.9003 validation accuracy :0.6314
# Epoch 86, CIFAR-10 Batch 3:  Loss:    0.9399 validation accuracy :0.6280
# Epoch 86, CIFAR-10 Batch 4:  Loss:    0.8597 validation accuracy :0.6256
# Epoch 86, CIFAR-10 Batch 5:  Loss:    0.8772 validation accuracy :0.6280
# Epoch 87, CIFAR-10 Batch 1:  Loss:    1.0106 validation accuracy :0.6194
# Epoch 87, CIFAR-10 Batch 2:  Loss:    0.8939 validation accuracy :0.6326
# Epoch 87, CIFAR-10 Batch 3:  Loss:    0.9357 validation accuracy :0.6246
# Epoch 87, CIFAR-10 Batch 4:  Loss:    0.8618 validation accuracy :0.6276
# Epoch 87, CIFAR-10 Batch 5:  Loss:    0.8831 validation accuracy :0.6208
# Epoch 88, CIFAR-10 Batch 1:  Loss:    1.0114 validation accuracy :0.6184
# Epoch 88, CIFAR-10 Batch 2:  Loss:    0.9051 validation accuracy :0.6282
# Epoch 88, CIFAR-10 Batch 3:  Loss:    0.9521 validation accuracy :0.6240
# Epoch 88, CIFAR-10 Batch 4:  Loss:    0.8577 validation accuracy :0.6260
# Epoch 88, CIFAR-10 Batch 5:  Loss:    0.8776 validation accuracy :0.6250
# Epoch 89, CIFAR-10 Batch 1:  Loss:    1.0129 validation accuracy :0.6194
# Epoch 89, CIFAR-10 Batch 2:  Loss:    0.8947 validation accuracy :0.6328
# Epoch 89, CIFAR-10 Batch 3:  Loss:    0.9540 validation accuracy :0.6208
# Epoch 89, CIFAR-10 Batch 4:  Loss:    0.8645 validation accuracy :0.6260
# Epoch 89, CIFAR-10 Batch 5:  Loss:    0.8793 validation accuracy :0.6236
# Epoch 90, CIFAR-10 Batch 1:  Loss:    1.0130 validation accuracy :0.6208
# Epoch 90, CIFAR-10 Batch 2:  Loss:    0.9021 validation accuracy :0.6310
# Epoch 90, CIFAR-10 Batch 3:  Loss:    0.9429 validation accuracy :0.6250
# Epoch 90, CIFAR-10 Batch 4:  Loss:    0.8620 validation accuracy :0.6250
# Epoch 90, CIFAR-10 Batch 5:  Loss:    0.8693 validation accuracy :0.6232
# Epoch 91, CIFAR-10 Batch 1:  Loss:    1.0110 validation accuracy :0.6170
# Epoch 91, CIFAR-10 Batch 2:  Loss:    0.8929 validation accuracy :0.6326
# Epoch 91, CIFAR-10 Batch 3:  Loss:    0.9471 validation accuracy :0.6214
# Epoch 91, CIFAR-10 Batch 4:  Loss:    0.8650 validation accuracy :0.6182
# Epoch 91, CIFAR-10 Batch 5:  Loss:    0.8835 validation accuracy :0.6188
# Epoch 92, CIFAR-10 Batch 1:  Loss:    1.0126 validation accuracy :0.6164
# Epoch 92, CIFAR-10 Batch 2:  Loss:    0.9065 validation accuracy :0.6280
# Epoch 92, CIFAR-10 Batch 3:  Loss:    0.9405 validation accuracy :0.6262
# Epoch 92, CIFAR-10 Batch 4:  Loss:    0.8540 validation accuracy :0.6274
# Epoch 92, CIFAR-10 Batch 5:  Loss:    0.8649 validation accuracy :0.6268
# Epoch 93, CIFAR-10 Batch 1:  Loss:    1.0100 validation accuracy :0.6138
# Epoch 93, CIFAR-10 Batch 2:  Loss:    0.9028 validation accuracy :0.6286
# Epoch 93, CIFAR-10 Batch 3:  Loss:    0.9363 validation accuracy :0.6268
# Epoch 93, CIFAR-10 Batch 4:  Loss:    0.8607 validation accuracy :0.6236
# Epoch 93, CIFAR-10 Batch 5:  Loss:    0.8751 validation accuracy :0.6252
# Epoch 94, CIFAR-10 Batch 1:  Loss:    1.0202 validation accuracy :0.6132
# Epoch 94, CIFAR-10 Batch 2:  Loss:    0.8933 validation accuracy :0.6318
# Epoch 94, CIFAR-10 Batch 3:  Loss:    0.9560 validation accuracy :0.6160
# Epoch 94, CIFAR-10 Batch 4:  Loss:    0.8555 validation accuracy :0.6234
# Epoch 94, CIFAR-10 Batch 5:  Loss:    0.8761 validation accuracy :0.6232
# Epoch 95, CIFAR-10 Batch 1:  Loss:    1.0031 validation accuracy :0.6162
# Epoch 95, CIFAR-10 Batch 2:  Loss:    0.8943 validation accuracy :0.6316
# Epoch 95, CIFAR-10 Batch 3:  Loss:    0.9355 validation accuracy :0.6258
# Epoch 95, CIFAR-10 Batch 4:  Loss:    0.8500 validation accuracy :0.6254
# Epoch 95, CIFAR-10 Batch 5:  Loss:    0.8806 validation accuracy :0.6220
# Epoch 96, CIFAR-10 Batch 1:  Loss:    1.0022 validation accuracy :0.6214
# Epoch 96, CIFAR-10 Batch 2:  Loss:    0.8950 validation accuracy :0.6270
# Epoch 96, CIFAR-10 Batch 3:  Loss:    0.9299 validation accuracy :0.6258
# Epoch 96, CIFAR-10 Batch 4:  Loss:    0.8478 validation accuracy :0.6246
# Epoch 96, CIFAR-10 Batch 5:  Loss:    0.8698 validation accuracy :0.6274
# Epoch 97, CIFAR-10 Batch 1:  Loss:    1.0039 validation accuracy :0.6206
# Epoch 97, CIFAR-10 Batch 2:  Loss:    0.8803 validation accuracy :0.6290
# Epoch 97, CIFAR-10 Batch 3:  Loss:    0.9529 validation accuracy :0.6162
# Epoch 97, CIFAR-10 Batch 4:  Loss:    0.8557 validation accuracy :0.6238
# Epoch 97, CIFAR-10 Batch 5:  Loss:    0.8719 validation accuracy :0.6238
# Epoch 98, CIFAR-10 Batch 1:  Loss:    1.0032 validation accuracy :0.6226
# Epoch 98, CIFAR-10 Batch 2:  Loss:    0.8892 validation accuracy :0.6314
# Epoch 98, CIFAR-10 Batch 3:  Loss:    0.9423 validation accuracy :0.6234
# Epoch 98, CIFAR-10 Batch 4:  Loss:    0.8548 validation accuracy :0.6254
# Epoch 98, CIFAR-10 Batch 5:  Loss:    0.8656 validation accuracy :0.6236
# Epoch 99, CIFAR-10 Batch 1:  Loss:    1.0001 validation accuracy :0.6248
# Epoch 99, CIFAR-10 Batch 2:  Loss:    0.8933 validation accuracy :0.6318
# Epoch 99, CIFAR-10 Batch 3:  Loss:    0.9414 validation accuracy :0.6270
# Epoch 99, CIFAR-10 Batch 4:  Loss:    0.8439 validation accuracy :0.6262
# Epoch 99, CIFAR-10 Batch 5:  Loss:    0.8660 validation accuracy :0.6258
# Epoch 100, CIFAR-10 Batch 1:  Loss:    0.9951 validation accuracy :0.6228
# Epoch 100, CIFAR-10 Batch 2:  Loss:    0.8958 validation accuracy :0.6316
# Epoch 100, CIFAR-10 Batch 3:  Loss:    0.9318 validation accuracy :0.6332
# Epoch 100, CIFAR-10 Batch 4:  Loss:    0.8475 validation accuracy :0.6238
# Epoch 100, CIFAR-10 Batch 5:  Loss:    0.8673 validation accuracy :0.6260

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6232307016849518

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
